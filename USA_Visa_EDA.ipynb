# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/us_perm_visas.csv")
df
# Out:
#        add_these_pw_job_title_9089 agent_city  \
# 0                              NaN        NaN
# 1                              NaN        NaN
# 2                              NaN        NaN
# 3                              NaN        NaN
# 4                              NaN        NaN
# ...                            ...        ...
# 365042                         NaN     Irvine
# 365043                         NaN    Atlanta
# 365044                         NaN     Boston
# 365045                         NaN  Royal Oak
# 365046                         NaN        NaN
#
#                                   agent_firm_name agent_state  \
# 0                                             NaN         NaN
# 1                                             NaN         NaN
# 2                                             NaN         NaN
# 3                                             NaN         NaN
# 4                                             NaN         NaN
# ...                                           ...         ...
# 365042    FRAGOMEN, DEL REY, BERNSEN & LOEWY, LLP          CA
# 365043  Fragomen, Del Rey, Bernsen and Loewy, LLP          GA
# 365044                          Seyfarth Shaw LLP          MA
# 365045                  Roby Law Associates, PLLC          MI
# 365046                                        NaN         NaN
#
#        application_type        case_no    case_number case_received_date  \
# 0                  PERM  A-07323-97014            NaN                NaN
# 1                  PERM  A-07332-99439            NaN                NaN
# 2                  PERM  A-07333-99643            NaN                NaN
# 3                  PERM  A-07339-01930            NaN                NaN
# 4                  PERM  A-07345-03565            NaN                NaN
# ...                 ...            ...            ...                ...
# 365042              NaN            NaN  A-16239-46995         2016-09-06
# 365043              NaN            NaN  A-16245-49069         2016-09-06
# 365044              NaN            NaN  A-16239-47013         2016-09-06
# 365045              NaN            NaN  A-16243-47732         2016-09-06
# 365046              NaN            NaN  A-16246-49439         2016-09-06
#
#        case_status class_of_admission  ... ri_pvt_employment_firm_to  \
# 0        Certified                J-1  ...                       NaN
# 1           Denied                B-2  ...                       NaN
# 2        Certified               H-1B  ...                       NaN
# 3        Certified                B-2  ...                       NaN
# 4        Certified                L-1  ...                       NaN
# ...            ...                ...  ...                       ...
# 365042   Certified                L-1  ...                       NaN
# 365043   Certified               H-1B  ...                       NaN
# 365044   Certified               H-1B  ...                       NaN
# 365045   Certified               H-1B  ...                       NaN
# 365046   Certified               H-1B  ...                       NaN
#
#        ri_us_workers_considered schd_a_sheepherder     us_economic_sector  \
# 0                           NaN                NaN                     IT
# 1                           NaN                NaN  Other Economic Sector
# 2                           NaN                NaN              Aerospace
# 3                           NaN                NaN  Other Economic Sector
# 4                           NaN                NaN           Advanced Mfg
# ...                         ...                ...                    ...
# 365042                      NaN                  N                    NaN
# 365043                      NaN                  N                    NaN
# 365044                      NaN                  N                    NaN
# 365045                      NaN                  N                    NaN
# 365046                      NaN                NaN                    NaN
#
#        wage_offer_from_9089 wage_offer_to_9089 wage_offer_unit_of_pay_9089  \
# 0                   75629.0                NaN                          yr
# 1                   37024.0                NaN                          yr
# 2                   47923.0                NaN                          yr
# 3                     10.97                NaN                          hr
# 4                  100000.0                NaN                          yr
# ...                     ...                ...                         ...
# 365042            98,426.00         100,000.00                        Year
# 365043            79,394.00          90,208.00                        Year
# 365044           116,355.00         148,700.00                        Year
# 365045            90,600.00                NaN                        Year
# 365046                  NaN                NaN                         NaN
#
#        wage_offered_from_9089 wage_offered_to_9089  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
# ...                       ...                  ...
# 365042                    NaN                  NaN
# 365043                    NaN                  NaN
# 365044                    NaN                  NaN
# 365045                    NaN                  NaN
# 365046                    NaN                  NaN
#
#         wage_offered_unit_of_pay_9089
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 365042                            NaN
# 365043                            NaN
# 365044                            NaN
# 365045                            NaN
# 365046                            NaN
#
# [365047 rows x 154 columns]

# %%
df.head()
# Out:
#   add_these_pw_job_title_9089 agent_city agent_firm_name agent_state  \
# 0                         NaN        NaN             NaN         NaN
# 1                         NaN        NaN             NaN         NaN
# 2                         NaN        NaN             NaN         NaN
# 3                         NaN        NaN             NaN         NaN
# 4                         NaN        NaN             NaN         NaN
#
#   application_type        case_no case_number case_received_date case_status  \
# 0             PERM  A-07323-97014         NaN                NaN   Certified
# 1             PERM  A-07332-99439         NaN                NaN      Denied
# 2             PERM  A-07333-99643         NaN                NaN   Certified
# 3             PERM  A-07339-01930         NaN                NaN   Certified
# 4             PERM  A-07345-03565         NaN                NaN   Certified
#
#   class_of_admission  ... ri_pvt_employment_firm_to ri_us_workers_considered  \
# 0                J-1  ...                       NaN                      NaN
# 1                B-2  ...                       NaN                      NaN
# 2               H-1B  ...                       NaN                      NaN
# 3                B-2  ...                       NaN                      NaN
# 4                L-1  ...                       NaN                      NaN
#
#   schd_a_sheepherder     us_economic_sector wage_offer_from_9089  \
# 0                NaN                     IT              75629.0
# 1                NaN  Other Economic Sector              37024.0
# 2                NaN              Aerospace              47923.0
# 3                NaN  Other Economic Sector                10.97
# 4                NaN           Advanced Mfg             100000.0
#
#   wage_offer_to_9089 wage_offer_unit_of_pay_9089 wage_offered_from_9089  \
# 0                NaN                          yr                    NaN
# 1                NaN                          yr                    NaN
# 2                NaN                          yr                    NaN
# 3                NaN                          hr                    NaN
# 4                NaN                          yr                    NaN
#
#   wage_offered_to_9089  wage_offered_unit_of_pay_9089
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
#
# [5 rows x 154 columns]

# %%
df.tail()
# Out:
#        add_these_pw_job_title_9089 agent_city  \
# 365042                         NaN     Irvine
# 365043                         NaN    Atlanta
# 365044                         NaN     Boston
# 365045                         NaN  Royal Oak
# 365046                         NaN        NaN
#
#                                   agent_firm_name agent_state  \
# 365042    FRAGOMEN, DEL REY, BERNSEN & LOEWY, LLP          CA
# 365043  Fragomen, Del Rey, Bernsen and Loewy, LLP          GA
# 365044                          Seyfarth Shaw LLP          MA
# 365045                  Roby Law Associates, PLLC          MI
# 365046                                        NaN         NaN
#
#        application_type case_no    case_number case_received_date case_status  \
# 365042              NaN     NaN  A-16239-46995         2016-09-06   Certified
# 365043              NaN     NaN  A-16245-49069         2016-09-06   Certified
# 365044              NaN     NaN  A-16239-47013         2016-09-06   Certified
# 365045              NaN     NaN  A-16243-47732         2016-09-06   Certified
# 365046              NaN     NaN  A-16246-49439         2016-09-06   Certified
#
#        class_of_admission  ... ri_pvt_employment_firm_to  \
# 365042                L-1  ...                       NaN
# 365043               H-1B  ...                       NaN
# 365044               H-1B  ...                       NaN
# 365045               H-1B  ...                       NaN
# 365046               H-1B  ...                       NaN
#
#        ri_us_workers_considered schd_a_sheepherder us_economic_sector  \
# 365042                      NaN                  N                NaN
# 365043                      NaN                  N                NaN
# 365044                      NaN                  N                NaN
# 365045                      NaN                  N                NaN
# 365046                      NaN                NaN                NaN
#
#        wage_offer_from_9089 wage_offer_to_9089 wage_offer_unit_of_pay_9089  \
# 365042            98,426.00         100,000.00                        Year
# 365043            79,394.00          90,208.00                        Year
# 365044           116,355.00         148,700.00                        Year
# 365045            90,600.00                NaN                        Year
# 365046                  NaN                NaN                         NaN
#
#        wage_offered_from_9089 wage_offered_to_9089  \
# 365042                    NaN                  NaN
# 365043                    NaN                  NaN
# 365044                    NaN                  NaN
# 365045                    NaN                  NaN
# 365046                    NaN                  NaN
#
#         wage_offered_unit_of_pay_9089
# 365042                            NaN
# 365043                            NaN
# 365044                            NaN
# 365045                            NaN
# 365046                            NaN
#
# [5 rows x 154 columns]

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
#        'foreign_worker_info_req_experience', 'foreign_worker_info_state',
#        'foreign_worker_info_training_comp',
#        'foreign_worker_ownership_interest',
#        'foreign_worker_yr_rel_edu_completed',
#        'fw_info_alt_edu_experience', 'fw_info_birth_country',
#        'fw_info_education_other', 'fw_info_postal_code',
#        'fw_info_rel_occup_exp', 'fw_info_req_experience',
#        'fw_info_training_comp', 'fw_info_yr_rel_edu_completed',
#        'fw_ownership_interest', 'ji_foreign_worker_live_on_premises',
#        'ji_fw_live_on_premises', 'ji_live_in_dom_svc_contract',
#        'ji_live_in_domestic_service',
#        'ji_offered_to_sec_j_foreign_worker', 'ji_offered_to_sec_j_fw',
#        'job_info_alt_cmb_ed_oth_yrs', 'job_info_alt_combo_ed',
#        'job_info_alt_combo_ed_exp', 'job_info_alt_combo_ed_other',
#        'job_info_alt_field', 'job_info_alt_field_name',
#        'job_info_alt_occ', 'job_info_alt_occ_job_title',
#        'job_info_alt_occ_num_months', 'job_info_combo_occupation',
#        'job_info_education', 'job_info_education_other',
#        'job_info_experience', 'job_info_experience_num_months',
#        'job_info_foreign_ed', 'job_info_foreign_lang_req',
#        'job_info_job_req_normal', 'job_info_job_title', 'job_info_major',
#        'job_info_training', 'job_info_training_field',
#        'job_info_training_num_months', 'job_info_work_city',
#        'job_info_work_postal_code', 'job_info_work_state',
#        'naics_2007_us_code', 'naics_2007_us_title', 'naics_code',
#        'naics_title', 'naics_us_code', 'naics_us_code_2007',
#        'naics_us_title', 'naics_us_title_2007', 'orig_case_no',
#        'orig_file_date', 'preparer_info_emp_completed',
#        'preparer_info_title', 'pw_amount_9089', 'pw_determ_date',
#        'pw_expire_date', 'pw_job_title_908', 'pw_job_title_9089',
#        'pw_level_9089', 'pw_soc_code', 'pw_soc_title',
#        'pw_source_name_9089', 'pw_source_name_other_9089', 'pw_track_num',
#        'pw_unit_of_pay_9089', 'rec_info_barg_rep_notified',
#        'recr_info_barg_rep_notified', 'recr_info_coll_teach_comp_proc',
#        'recr_info_coll_univ_teacher', 'recr_info_employer_rec_payment',
#        'recr_info_first_ad_start', 'recr_info_job_fair_from',
#        'recr_info_job_fair_to', 'recr_info_on_campus_recr_from',
#        'recr_info_on_campus_recr_to', 'recr_info_pro_org_advert_from',
#        'recr_info_pro_org_advert_to', 'recr_info_prof_org_advert_from',
#        'recr_info_prof_org_advert_to', 'recr_info_professional_occ',
#        'recr_info_radio_tv_ad_from', 'recr_info_radio_tv_ad_to',
#        'recr_info_second_ad_start', 'recr_info_sunday_newspaper',
#        'recr_info_swa_job_order_end', 'recr_info_swa_job_order_start',
#        'refile', 'ri_1st_ad_newspaper_name', 'ri_2nd_ad_newspaper_name',
#        'ri_2nd_ad_newspaper_or_journal', 'ri_campus_placement_from',
#        'ri_campus_placement_to', 'ri_coll_tch_basic_process',
#        'ri_coll_teach_pro_jnl', 'ri_coll_teach_select_date',
#        'ri_employee_referral_prog_from', 'ri_employee_referral_prog_to',
#        'ri_employer_web_post_from', 'ri_employer_web_post_to',
#        'ri_job_search_website_from', 'ri_job_search_website_to',
#        'ri_layoff_in_past_six_months', 'ri_local_ethnic_paper_from',
#        'ri_local_ethnic_paper_to', 'ri_posted_notice_at_worksite',
#        'ri_pvt_employment_firm_from', 'ri_pvt_employment_firm_to',
#        'ri_us_workers_considered', 'schd_a_sheepherder',
#        'us_economic_sector', 'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089'],
#       dtype=object)

# %%
df.dtypes
# Out:
# add_these_pw_job_title_9089       object
# agent_city                        object
# agent_firm_name                   object
# agent_state                       object
# application_type                  object
#                                   ...
# wage_offer_to_9089                object
# wage_offer_unit_of_pay_9089       object
# wage_offered_from_9089           float64
# wage_offered_to_9089             float64
# wage_offered_unit_of_pay_9089     object
# Length: 154, dtype: object

# %%
df.isnull().sum()
# Out:
# add_these_pw_job_title_9089      322853
# agent_city                       162280
# agent_firm_name                  166567
# agent_state                      165373
# application_type                 229778
#                                   ...
# wage_offer_to_9089               293969
# wage_offer_unit_of_pay_9089      115913
# wage_offered_from_9089           250400
# wage_offered_to_9089             334032
# wage_offered_unit_of_pay_9089    294348
# Length: 154, dtype: int64

# %%
df["case_no"]
# Out:
# 0         A-07323-97014
# 1         A-07332-99439
# 2         A-07333-99643
# 3         A-07339-01930
# 4         A-07345-03565
#               ...
# 365042              NaN
# 365043              NaN
# 365044              NaN
# 365045              NaN
# 365046              NaN
# Name: case_no, Length: 365047, dtype: object

# %%
df["case_no"].nunique()
# Out:
# 134990

# %%
df["case_number"]
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#               ...
# 365042    A-16239-46995
# 365043    A-16245-49069
# 365044    A-16239-47013
# 365045    A-16243-47732
# 365046    A-16246-49439
# Name: case_number, Length: 365047, dtype: object

# %%
df["case_number"].nunique()
# Out:
# 229215

# %%
134990+238418
# Out:
# 373408

# %%
df.case_number.isna().sum()
# Out:
# 135269

# %%
casenoindex = df.columns.get_loc("case_no")
casenumberindex = df.columns.get_loc("case_number")
case_numbers = []

for value in df.iloc[0:135269, casenoindex]:
    case_numbers.append(value)

for value in df.iloc[135269:374362, casenumberindex]:
    case_numbers.append(value)

case_numbers
# Out:
# ['A-07323-97014',
#  'A-07332-99439',
#  'A-07333-99643',
#  'A-07339-01930',
#  'A-07345-03565',
#  'A-07352-06288',
#  'A-07354-06926',
#  'A-08004-10147',
#  'A-08004-10184',
#  'A-08010-11785',
#  'A-08057-27232',
#  'A-08058-28001',
#  'A-08076-33611',
#  'A-08085-36053',
#  'A-08104-41821',
#  'A-08120-47187',
#  'A-08127-49255',
#  'A-08148-55775',
#  'A-08162-60225',
#  'A-08164-61023',
#  'A-08176-64095',
#  'A-08182-66284',
#  'A-08190-68131',
#  'A-08190-68200',
#  'A-08271-91261',
#  'A-08200-71216',
#  'A-08203-71676',
#  'A-08211-73870',
#  'A-08211-74089',
#  'A-08212-74295',
#  'A-08220-76622',
#  'A-08221-77017',
#  'A-08221-77195',
#  'A-08224-77312',
#  'A-08225-77723',
#  'A-08227-78536',
#  'A-08238-81419',
#  'A-08238-81533',
#  'A-08240-82338',
#  'A-08241-82750',
#  'A-08246-83350',
#  'A-08247-83629',
#  'A-08254-85569',
#  'A-08255-86138',
#  'A-08259-87626',
#  'A-08260-88111',
#  'A-08264-89308',
#  'A-08267-89752',
#  'A-08267-89878',
#  'A-08270-91040',
#  'A-08276-92533',
#  'A-08276-92560',
#  'A-08280-93353',
#  'A-08280-93404',
#  'A-08280-93430',
#  'A-08284-94914',
#  'A-08284-95050',
#  'A-08288-95794',
#  'A-08288-95916',
#  'A-08291-96775',
#  'A-08291-96813',
#  'A-08291-96847',
#  'A-08291-97042',
#  'A-06353-92851',
#  'A-07004-96978',
#  'A-07165-46663',
#  'A-07213-62416',
#  'A-07237-69481',
#  'A-07239-69694',
#  'A-07257-75661',
#  'A-07264-77890',
#  'A-07270-79789',
#  'A-07299-89765',
#  'A-07311-93198',
#  'A-08296-98212',
#  'A-08298-99062',
#  'A-08301-99632',
#  'A-08305-01526',
#  'A-08309-02134',
#  'A-08310-02671',
#  'A-08318-05127',
#  'A-08318-05168',
#  'A-08319-05713',
#  'A-08319-05779',
#  'A-08319-05869',
#  'A-08322-06232',
#  'A-08323-06892',
#  'A-08325-07733',
#  'A-08326-08188',
#  'A-08330-08993',
#  'A-08331-09735',
#  'A-08331-09808',
#  'A-08336-10229',
#  'A-08339-11458',
#  'A-08343-12017',
#  'A-08344-12339',
#  'A-08344-12366',
#  'A-08346-13198',
#  'A-08347-13759',
#  'A-08351-14351',
#  'A-08352-14847',
#  'A-08353-15254',
#  'A-08353-15262',
#  'A-08353-15371',
#  'A-08353-15426',
#  'A-08354-15600',
#  'A-08354-15603',
#  'A-08359-16750',
#  'A-08364-16848',
#  'A-08364-16914',
#  'A-08366-17436',
#  'A-09006-18173',
#  'A-09007-18575',
#  'A-09007-18596',
#  'A-09008-19044',
#  'A-09008-19148',
#  'A-09009-19507',
#  'A-09012-19630',
#  'A-09012-19875',
#  'A-09012-19921',
#  'A-09013-20308',
#  'A-09014-20804',
#  'A-09016-21356',
#  'A-09016-21364',
#  'A-09016-21425',
#  'A-09016-21537',
#  'A-09020-22022',
#  'A-09021-22363',
#  'A-09021-22406',
#  'A-09022-22801',
#  'A-09022-22945',
#  'A-09028-24162',
#  'A-09028-24306',
#  'A-09030-24767',
#  'A-09030-24939',
#  'A-09034-25500',
#  'A-09035-25632',
#  'A-09035-25841',
#  'A-09037-26289',
#  'A-09041-26827',
#  'A-09042-27184',
#  'A-09042-27253',
#  'A-09043-27667',
#  'A-09044-27832',
#  'A-09047-28070',
#  'A-09047-28120',
#  'A-09051-29262',
#  'A-09054-29578',
#  'A-09056-30001',
#  'A-09056-30267',
#  'A-09058-30615',
#  'A-09058-30808',
#  'A-09063-31668',
#  'A-09063-31791',
#  'A-09064-31823',
#  'A-09064-32082',
#  'A-09066-32390',
#  'A-09068-32685',
#  'A-09071-33284',
#  'A-09072-33587',
#  'A-09072-33693',
#  'A-09075-33825',
#  'A-09076-34048',
#  'A-09076-34255',
#  'A-09077-34342',
#  'A-09079-34927',
#  'A-09082-35210',
#  'A-09089-36357',
#  'A-09089-36437',
#  'A-09092-37032',
#  'A-09092-37186',
#  'A-09093-37250',
#  'A-09093-37410',
#  'A-09096-37657',
#  'A-09097-37911',
#  'A-09098-38279',
#  'A-09099-38442',
#  'A-09099-38487',
#  'A-09100-38691',
#  'A-09100-38758',
#  'A-09100-38836',
#  'A-09103-39074',
#  'A-09105-39507',
#  'A-09105-39567',
#  'A-09106-39960',
#  'A-09106-40012',
#  'A-09113-41123',
#  'A-09113-41258',
#  'A-09114-41395',
#  'A-09114-41589',
#  'A-09118-41997',
#  'A-09118-42113',
#  'A-09119-42349',
#  'A-09120-42475',
#  'A-09120-42541',
#  'A-09120-42560',
#  'A-09120-42664',
#  'A-09121-42750',
#  'A-09121-42832',
#  'A-09125-43302',
#  'A-09126-43544',
#  'A-09126-43639',
#  'A-09126-43697',
#  'A-09127-43815',
#  'A-09127-43868',
#  'A-09128-44064',
#  'A-09132-44724',
#  'A-09133-44759',
#  'A-09134-45101',
#  'A-09138-45536',
#  'A-09139-45734',
#  'A-09139-45805',
#  'A-09139-45864',
#  'A-09140-46024',
#  'A-09140-46083',
#  'A-09140-46119',
#  'A-09140-46123',
#  'A-09140-46241',
#  'A-09141-46260',
#  'A-09141-46437',
#  'A-09142-46484',
#  'A-09142-46540',
#  'A-09142-46567',
#  'A-09143-46679',
#  'A-09146-46827',
#  'A-09146-46927',
#  'A-09146-46936',
#  'A-09147-47018',
#  'A-09147-47036',
#  'A-09147-47170',
#  'A-09148-47246',
#  'A-09148-47467',
#  'A-09149-47730',
#  'A-09152-47853',
#  'A-09153-48061',
#  'A-09153-48176',
#  'A-09155-48567',
#  'A-09155-48573',
#  'A-09155-48647',
#  'A-09156-48769',
#  'A-11181-89692',
#  'A-09156-48808',
#  'A-09156-48863',
#  'A-09160-49202',
#  'A-09160-49285',
#  'A-09160-49295',
#  'A-09162-49723',
#  'A-09162-49890',
#  'A-09163-49954',
#  'A-09166-50131',
#  'A-09166-50178',
#  'A-09166-50179',
#  'A-09166-50219',
#  'A-09167-50353',
#  'A-09167-50459',
#  'A-09167-50549',
#  'A-09169-50871',
#  'A-09169-50921',
#  'A-09169-50952',
#  'A-09170-51208',
#  'A-09170-51214',
#  'A-09170-51233',
#  'A-09170-51235',
#  'A-09170-51245',
#  'A-09171-51272',
#  'A-09171-51277',
#  'A-09173-51505',
#  'A-09174-51630',
#  'A-09174-51797',
#  'A-09175-51903',
#  'A-09175-51927',
#  'A-09176-52108',
#  'A-09176-52331',
#  'A-09180-52587',
#  'A-09180-52610',
#  'A-09180-52614',
#  'A-09180-52815',
#  'A-09180-52835',
#  'A-09181-53025',
#  'A-09181-53136',
#  'A-09182-53212',
#  'A-09182-53328',
#  'A-09183-53455',
#  'A-09183-53463',
#  'A-09184-53605',
#  'A-09184-53613',
#  'A-09187-53703',
#  'A-09188-53898',
#  'A-09189-54057',
#  'A-09189-54155',
#  'A-09190-54262',
#  'A-09190-54270',
#  'A-09190-54323',
#  'A-09191-54617',
#  'A-09194-54698',
#  'A-09194-54798',
#  'A-09195-54975',
#  'A-09195-55024',
#  'A-09195-55045',
#  'A-09196-55323',
#  'A-09197-55522',
#  'A-09198-55624',
#  'A-09201-55906',
#  'A-09202-56164',
#  'A-09204-56649',
#  'A-09204-56726',
#  'A-09205-56793',
#  'A-09208-56970',
#  'A-09208-57110',
#  'A-09209-57234',
#  'A-09209-57326',
#  'A-09209-57380',
#  'A-09210-57449',
#  'A-09210-57499',
#  'A-09210-57532',
#  'A-09211-57711',
#  'A-09212-57852',
#  'A-09212-57903',
#  'A-09212-57945',
#  'A-09214-58032',
#  'A-09215-58207',
#  'A-09216-58439',
#  'A-09217-58500',
#  'A-09217-58586',
#  'A-09217-58619',
#  'A-09218-58640',
#  'A-09222-59193',
#  'A-09224-59553',
#  'A-09225-59762',
#  'A-09226-59937',
#  'A-09226-59979',
#  'A-09229-60210',
#  'A-09229-60259',
#  'A-09230-60314',
#  'A-09230-60326',
#  'A-09231-60483',
#  'A-09232-60696',
#  'A-09232-60713',
#  'A-09232-60786',
#  'A-09236-61059',
#  'A-09236-61092',
#  'A-09237-61282',
#  'A-09238-61568',
#  'A-09238-61706',
#  'A-09238-61724',
#  'A-09239-61829',
#  'A-09240-61959',
#  'A-09240-61960',
#  'A-09243-62157',
#  'A-09243-62190',
#  'A-09243-62276',
#  'A-09244-62379',
#  'A-09244-62412',
#  'A-09244-62500',
#  'A-09245-62600',
#  'A-09245-62740',
#  'A-09246-62826',
#  'A-09246-62837',
#  'A-09246-62878',
#  'A-09246-62902',
#  'A-09247-63070',
#  'A-09247-63113',
#  'A-09251-63392',
#  'A-09252-63596',
#  'A-09253-63726',
#  'A-09253-63867',
#  'A-09254-63892',
#  'A-09254-63953',
#  'A-09254-64010',
#  'A-09257-64174',
#  'A-09257-64180',
#  'A-09257-64237',
#  'A-09258-64339',
#  'A-09258-64379',
#  'A-09258-64516',
#  'A-09260-64753',
#  'A-09260-64970',
#  'A-09265-65534',
#  'A-09266-65623',
#  'A-09266-65630',
#  'A-09267-65884',
#  'A-09267-65932',
#  'A-09268-66039',
#  'A-09268-66053',
#  'A-09268-66059',
#  'A-09268-66090',
#  'A-09268-66151',
#  'A-09270-66236',
#  'A-09271-66306',
#  'A-09271-66406',
#  'A-09272-66521',
#  'A-09272-66530',
#  'A-09272-66531',
#  'A-09272-66603',
#  'A-09272-66645',
#  'A-09272-66667',
#  'A-09273-66936',
#  'A-09273-67004',
#  'A-09273-67026',
#  'A-09274-67071',
#  'A-09274-67150',
#  'A-09274-67245',
#  'A-09274-67251',
#  'A-09275-67388',
#  'A-09275-67418',
#  'A-09275-67478',
#  'A-09278-67559',
#  'A-09279-67850',
#  'A-09279-67895',
#  'A-09280-68031',
#  'A-09280-68047',
#  'A-09281-68212',
#  'A-09281-68294',
#  'A-09281-68318',
#  'A-09282-68351',
#  'A-09282-68446',
#  'A-09285-68552',
#  'A-09287-68884',
#  'A-09287-68968',
#  'A-09287-68974',
#  'A-09287-69046',
#  'A-09288-69216',
#  'A-09291-69464',
#  'A-09293-69870',
#  'A-09294-69982',
#  'A-09295-70276',
#  'A-09296-70361',
#  'A-09299-70577',
#  'A-09299-70683',
#  'A-09300-70767',
#  'A-09300-70898',
#  'A-09300-70960',
#  'A-09301-71150',
#  'A-09301-71158',
#  'A-09302-71244',
#  'A-09302-71259',
#  'A-09302-71340',
#  'A-09303-71365',
#  'A-09307-71902',
#  'A-09308-71985',
#  'A-09309-72267',
#  'A-09309-72321',
#  'A-09313-72715',
#  'A-09313-72721',
#  'A-09314-72800',
#  'A-09314-72955',
#  'A-09315-73022',
#  'A-09315-73041',
#  'A-09315-73045',
#  'A-09315-73103',
#  'A-09316-73359',
#  'A-09318-73598',
#  'A-09320-73644',
#  'A-09320-73827',
#  'A-09320-73831',
#  'A-09321-73867',
#  'A-09321-73878',
#  'A-09321-73884',
#  'A-09321-73916',
#  'A-09321-74014',
#  'A-09322-74099',
#  'A-09322-74133',
#  'A-09322-74146',
#  'A-09323-74254',
#  'A-11236-01746',
#  'A-09324-74527',
#  'A-09327-74846',
#  'A-09327-74868',
#  'A-09328-74993',
#  'A-09329-75095',
#  'A-09329-75115',
#  'A-09329-75120',
#  'A-09329-75157',
#  'A-09329-75180',
#  'A-09334-75260',
#  'A-09334-75280',
#  'A-09334-75301',
#  'A-09334-75318',
#  'A-09334-75367',
#  'A-09335-75528',
#  'A-09335-75572',
#  'A-09336-75821',
#  'A-09336-75822',
#  'A-09336-75837',
#  'A-09336-75844',
#  'A-09336-75913',
#  'A-09337-75975',
#  'A-09337-76018',
#  'A-09337-76021',
#  'A-09337-76056',
#  'A-09337-76066',
#  'A-09337-76132',
#  'A-09338-76142',
#  'A-09338-76223',
#  'A-09338-76254',
#  'A-09338-76255',
#  'A-09338-76272',
#  'A-09338-76291',
#  'A-09338-76312',
#  'A-09338-76334',
#  'A-09341-76372',
#  'A-09341-76388',
#  'A-09341-76431',
#  'A-09341-76451',
#  'A-09341-76496',
#  'A-09341-76567',
#  'A-09341-76580',
#  'A-09341-76589',
#  'A-09342-76605',
#  'A-09343-76951',
#  'A-09343-76973',
#  'A-09343-76993',
#  'A-09343-76997',
#  'A-10052-87197',
#  'A-09344-77197',
#  'A-09345-77213',
#  'A-09345-77289',
#  'A-09348-77520',
#  'A-09348-77580',
#  'A-09348-77585',
#  'A-09349-77791',
#  'A-09349-77820',
#  'A-09350-77845',
#  'A-09350-77910',
#  'A-09350-77924',
#  'A-09350-77991',
#  'A-09350-78076',
#  'A-09351-78255',
#  'A-09352-78325',
#  'A-09352-78374',
#  'A-09352-78482',
#  'A-09355-78510',
#  'A-09355-78580',
#  'A-09355-78653',
#  'A-09355-78672',
#  'A-09356-78904',
#  'A-09357-78910',
#  'A-09357-78968',
#  'A-09357-79057',
#  'A-09357-79128',
#  'A-09358-79160',
#  'A-09361-79220',
#  'A-09362-79284',
#  'A-09362-79345',
#  'A-09362-79402',
#  'A-09363-79427',
#  'A-09364-79633',
#  'A-09364-79687',
#  'A-09364-79741',
#  'A-09365-79848',
#  'A-10005-80110',
#  'A-10005-80164',
#  'A-10006-80421',
#  'A-10006-80468',
#  'A-10006-80562',
#  'A-10007-80591',
#  'A-10008-80909',
#  'A-10008-80935',
#  'A-10008-80942',
#  'A-10010-80988',
#  'A-10011-81225',
#  'A-10011-81241',
#  'A-10012-81324',
#  'A-10012-81368',
#  'A-10013-81590',
#  'A-10015-82063',
#  'A-10019-82330',
#  'A-10019-82334',
#  'A-10019-82362',
#  'A-10019-82374',
#  'A-10019-82439',
#  'A-10020-82543',
#  'A-11278-09939',
#  'A-10022-83144',
#  'A-10026-83430',
#  'A-10026-83458',
#  'A-10032-84400',
#  'A-10034-84930',
#  'A-10035-85031',
#  'A-10035-85064',
#  'A-10036-85322',
#  'A-10040-85691',
#  'A-10041-85982',
#  'A-10043-86241',
#  'A-10046-86438',
#  'A-10048-86677',
#  'A-10049-86874',
#  'A-10050-87100',
#  'A-10053-87265',
#  'A-10055-87662',
#  'A-10055-87759',
#  'A-10055-87762',
#  'A-10060-88301',
#  'A-10060-88303',
#  'A-10061-88367',
#  'A-10061-88412',
#  'A-10159-02552',
#  'A-10061-88444',
#  'A-10061-88525',
#  'A-10061-88538',
#  'A-10062-88700',
#  'A-10062-88716',
#  'A-10063-88833',
#  'A-10063-88913',
#  'A-10063-88940',
#  'A-10064-89085',
#  'A-10067-89347',
#  'A-10067-89413',
#  'A-10068-89423',
#  'A-10068-89483',
#  'A-10068-89487',
#  'A-10068-89489',
#  'A-10069-89740',
#  'A-10069-89834',
#  'A-10069-89851',
#  'A-10069-89893',
#  'A-10071-90195',
#  'A-10071-90221',
#  'A-10071-90251',
#  'A-10074-90310',
#  'A-10076-90679',
#  'A-10076-90737',
#  'A-10077-90963',
#  'A-10078-90988',
#  'A-10078-91101',
#  'A-10080-91163',
#  'A-10081-91257',
#  'A-10081-91259',
#  'A-10081-91370',
#  'A-10082-91423',
#  'A-10082-91470',
#  'A-10083-91611',
#  'A-10083-91719',
#  'A-10085-92000',
#  'A-10087-92250',
#  'A-10088-92352',
#  'A-10088-92395',
#  'A-10088-92401',
#  'A-10089-92490',
#  'A-10090-92816',
#  'A-10091-92953',
#  'A-10091-93026',
#  'A-10091-93030',
#  'A-10091-93033',
#  'A-10091-93035',
#  'A-10095-93274',
#  'A-10095-93336',
#  'A-10097-93610',
#  'A-10097-93787',
#  'A-10098-93816',
#  'A-10099-94077',
#  'A-10104-94557',
#  'A-10104-94567',
#  'A-10104-94683',
#  'A-10105-94846',
#  'A-10109-95233',
#  'A-10111-95582',
#  'A-10111-95592',
#  'A-10113-95947',
#  'A-10116-96235',
#  'A-10117-96318',
#  'A-10117-96364',
#  'A-10117-96467',
#  'A-10119-96684',
#  'A-10119-96700',
#  'A-10120-96892',
#  'A-10120-96895',
#  'A-10161-02838',
#  'A-10120-96899',
#  'A-10125-97562',
#  'A-10127-97899',
#  'A-10127-97954',
#  'A-10130-98232',
#  'A-10131-98348',
#  'A-10131-98455',
#  'A-10132-98761',
#  'A-10132-98813',
#  'A-10139-99894',
#  'A-10140-99936',
#  'A-10144-00478',
#  'A-10147-00911',
#  'A-10148-01127',
#  'A-10148-01168',
#  'A-10148-01277',
#  'A-10152-01478',
#  'A-10154-01821',
#  'A-10155-02053',
#  'A-10158-02164',
#  'A-10158-02198',
#  'A-10158-02227',
#  'A-10158-02259',
#  'A-10159-02483',
#  'A-10161-02907',
#  'A-10161-02963',
#  'A-10162-03028',
#  'A-10162-03109',
#  'A-10162-03139',
#  'A-10166-03469',
#  'A-10166-03588',
#  'A-10168-03938',
#  'A-10168-04102',
#  'A-10172-04616',
#  'A-10173-04822',
#  'A-10173-04829',
#  'A-10173-04852',
#  'A-10173-04854',
#  'A-10173-04856',
#  'A-10300-28029',
#  'A-10173-04865',
#  'A-10174-04976',
#  'A-10174-04979',
#  'A-10174-05048',
#  'A-10174-05075',
#  'A-10174-05090',
#  'A-10175-05176',
#  'A-10175-05239',
#  'A-10175-05377',
#  'A-10176-05529',
#  'A-10176-05583',
#  'A-10176-05613',
#  'A-10176-05622',
#  'A-10177-05665',
#  'A-10178-05694',
#  'A-10178-05695',
#  'A-10178-05706',
#  'A-10178-05717',
#  'A-10178-05724',
#  'A-10178-05726',
#  'A-10178-05737',
#  'A-10178-05738',
#  'A-10178-05740',
#  'A-10178-05745',
#  'A-10178-05747',
#  'A-10323-33262',
#  'A-10326-33551',
#  'A-10326-33605',
#  'A-10326-33625',
#  'A-10327-33738',
#  'A-10327-33787',
#  'A-10327-33816',
#  'A-10328-34187',
#  'A-10330-34316',
#  'A-10330-34332',
#  'A-10333-34473',
#  'A-10333-34481',
#  'A-10333-34524',
#  'A-10333-34549',
#  'A-10333-34551',
#  'A-10333-34706',
#  'A-10333-34724',
#  'A-10333-34736',
#  'A-10350-39548',
#  'A-10334-34853',
#  'A-10334-34874',
#  'A-10334-34890',
#  'A-10335-35055',
#  'A-10335-35089',
#  'A-10246-17426',
#  'A-10335-35099',
#  'A-10335-35252',
#  'A-10335-35365',
#  'A-10335-35413',
#  'A-10335-35416',
#  'A-10336-35509',
#  'A-10336-35564',
#  'A-10336-35581',
#  'A-10336-35587',
#  'A-10336-35616',
#  'A-10336-35640',
#  'A-10337-35903',
#  'A-10337-36008',
#  'A-10337-36094',
#  'A-10340-36452',
#  'A-10340-36542',
#  'A-10340-36675',
#  'A-10340-36753',
#  'A-10279-23849',
#  'A-10341-36923',
#  'A-10341-37122',
#  'A-10342-37216',
#  'A-10342-37226',
#  'A-10342-37410',
#  'A-10342-37413',
#  'A-10342-37458',
#  'A-10343-37626',
#  'A-10343-37752',
#  'A-10343-37874',
#  'A-10343-37961',
#  'A-10344-38058',
#  'A-10344-38301',
#  'A-10347-38445',
#  'A-10347-38463',
#  'A-10347-38553',
#  'A-10178-05749',
#  'A-10178-05750',
#  'A-10179-05808',
#  'A-10179-05883',
#  'A-10179-05904',
#  'A-10179-05909',
#  'A-10179-06006',
#  'A-10300-28007',
#  'A-10179-06018',
#  'A-10180-06045',
#  'A-10180-06061',
#  'A-10180-06082',
#  'A-10180-06111',
#  'A-10180-06118',
#  'A-10180-06140',
#  'A-10180-06246',
#  'A-10180-06258',
#  'A-10180-06271',
#  'A-10180-06273',
#  'A-10180-06308',
#  'A-10180-06327',
#  'A-10180-06351',
#  'A-10181-06356',
#  'A-10181-06359',
#  'A-10181-06419',
#  'A-10181-06425',
#  'A-10181-06434',
#  'A-10181-06442',
#  'A-10181-06445',
#  'A-10181-06452',
#  'A-10181-06460',
#  'A-10181-06482',
#  'A-10181-06533',
#  'A-10181-06549',
#  'A-10181-06550',
#  'A-10181-06554',
#  'A-10181-06569',
#  'A-10181-06578',
#  'A-10181-06611',
#  'A-10181-06628',
#  'A-10183-06970',
#  'A-10187-07219',
#  'A-10188-07408',
#  'A-10188-07409',
#  'A-10188-07414',
#  'A-10191-07880',
#  'A-10193-08105',
#  'A-10194-08153',
#  'A-10194-08295',
#  'A-10195-08421',
#  'A-10195-08476',
#  'A-10197-08845',
#  'A-10219-12547',
#  'A-10197-08861',
#  'A-10197-08906',
#  'A-10197-08947',
#  'A-10197-08991',
#  'A-10200-09144',
#  'A-10200-09287',
#  'A-10201-09316',
#  'A-10202-09659',
#  'A-10208-10501',
#  'A-10210-11021',
#  'A-10210-11044',
#  'A-10210-11082',
#  'A-10210-11087',
#  'A-10213-11316',
#  'A-10214-11351',
#  'A-10214-11372',
#  'A-10214-11428',
#  'A-10214-11442',
#  'A-10215-11552',
#  'A-10215-11607',
#  'A-10217-12067',
#  'A-10217-12122',
#  'A-10217-12184',
#  'A-10218-12388',
#  'A-11263-07017',
#  'A-10221-12681',
#  'A-10224-13371',
#  'A-10225-13591',
#  'A-10229-14049',
#  'A-10229-14137',
#  'A-10229-14163',
#  'A-10230-14381',
#  'A-10230-14471',
#  'A-10230-14514',
#  'A-10231-14554',
#  'A-10235-15134',
#  'A-10236-15506',
#  'A-10237-15557',
#  'A-10237-15624',
#  'A-10239-16070',
#  'A-10242-16391',
#  'A-10242-16478',
#  'A-10243-16620',
#  'A-10243-16647',
#  'A-10243-16729',
#  'A-10244-17017',
#  'A-10245-17292',
#  'A-10245-17302',
#  'A-10246-17492',
#  'A-10246-17531',
#  'A-10250-17703',
#  'A-10250-17722',
#  'A-10250-17732',
#  'A-10250-17823',
#  'A-10251-18039',
#  'A-10251-18155',
#  'A-10252-18263',
#  'A-10252-18366',
#  'A-10252-18393',
#  'A-10252-18466',
#  'A-10256-18902',
#  'A-10256-18927',
#  'A-10256-18958',
#  'A-10256-19010',
#  'A-10256-19077',
#  'A-10256-19150',
#  'A-10257-19160',
#  'A-10257-19194',
#  'A-10257-19231',
#  'A-10257-19280',
#  'A-10258-19487',
#  'A-10258-19534',
#  'A-10260-20057',
#  'A-10261-20265',
#  'A-10262-20293',
#  'A-10263-20534',
#  'A-10264-20644',
#  'A-10264-20806',
#  'A-10265-20955',
#  'A-10266-21206',
#  'A-10266-21402',
#  'A-10267-21451',
#  'A-10272-22225',
#  'A-10272-22278',
#  'A-10273-22515',
#  'A-10273-22662',
#  'A-10273-22707',
#  'A-10273-22721',
#  'A-10274-22884',
#  'A-10277-23105',
#  'A-10277-23142',
#  'A-10277-23221',
#  'A-10278-23309',
#  'A-10278-23426',
#  'A-10279-23791',
#  'A-10281-24305',
#  'A-10284-24467',
#  'A-10285-24682',
#  'A-10287-25299',
#  'A-10287-25328',
#  'A-10288-25555',
#  'A-10291-25867',
#  'A-10291-25888',
#  'A-10292-26172',
#  'A-10292-26203',
#  'A-10292-26215',
#  'A-10293-26400',
#  'A-10293-26554',
#  'A-10293-26558',
#  'A-10294-26785',
#  'A-10294-26937',
#  'A-10298-27281',
#  'A-10299-27779',
#  'A-10300-27822',
#  'A-10300-27836',
#  'A-10300-27862',
#  'A-10300-27927',
#  'A-10300-27944',
#  'A-10300-27957',
#  'A-10300-28030',
#  'A-10301-28209',
#  'A-10301-28373',
#  'A-10302-28644',
#  'A-10302-28660',
#  'A-10302-28665',
#  'A-10305-28945',
#  'A-10305-28960',
#  'A-10305-28977',
#  'A-10305-28981',
#  'A-10305-28988',
#  'A-10305-29103',
#  'A-10306-29255',
#  'A-10306-29262',
#  'A-10306-29358',
#  'A-10307-29484',
#  'A-10307-29513',
#  'A-10307-29706',
#  'A-10308-29881',
#  'A-10308-29971',
#  'A-10308-30008',
#  'A-10309-30142',
#  'A-10309-30217',
#  'A-10312-30693',
#  'A-10313-30781',
#  'A-10313-30833',
#  'A-10313-30882',
#  'A-10313-30985',
#  'A-10313-31059',
#  'A-10313-31067',
#  'A-10314-31111',
#  'A-10314-31302',
#  'A-10314-31396',
#  'A-10315-31490',
#  'A-10315-31604',
#  ...]

# %%
df["case_numbers"] = case_numbers

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_us_workers_considered', 'schd_a_sheepherder', 'us_economic_sector',
#        'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089',
#        'case_numbers'],
#       dtype='object', length=155)

# %%
df['case_status'].unique()
# Out:
# array(['Certified', 'Denied', 'Certified-Expired', 'Withdrawn'],
#       dtype=object)

# %%
df["case_status"].value_counts()
# Out:
# case_status
# Certified            173540
# Certified-Expired    148586
# Denied                25031
# Withdrawn             17890
# Name: count, dtype: int64

# %%
#remove withdraw values
df = df[df["case_status"] != "Withdrawn"]

# %%
df["case_status"].value_counts()
# Out:
# case_status
# Certified            173540
# Certified-Expired    148586
# Denied                25031
# Name: count, dtype: int64

# %%
df.loc[df.case_status == "Certified-Expired","case_status"] = 'Certified'

# %%
df["case_status"].value_counts()
# Out:
# case_status
# Certified    322126
# Denied        25031
# Name: count, dtype: int64

# %%
round(df["case_status"].value_counts(normalize=True)*100,2)
# Out:
# case_status
# Certified    92.79
# Denied        7.21
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (8,8))
sns.countplot(x='case_status', data=df, palette = "viridis")
plt.show()

# %%
df.dropna(axis=1,how="all",inplace = True)
df.dropna(axis =0, how = "all", inplace  = True)

# %%
#missing values
for col in df.columns:
  print(f" the missing value of ' {col} ' is :- {df[col].isnull().sum()}")
# Out:
#  the missing value of ' add_these_pw_job_title_9089 ' is :- 308020
#  the missing value of ' agent_city ' is :- 152842
#  the missing value of ' agent_firm_name ' is :- 156873
#  the missing value of ' agent_state ' is :- 155815
#  the missing value of ' application_type ' is :- 220309
#  the missing value of ' case_no ' is :- 220309
#  the missing value of ' case_number ' is :- 126848
#  the missing value of ' case_received_date ' is :- 126848
#  the missing value of ' case_status ' is :- 0
#  the missing value of ' class_of_admission ' is :- 20368
#  the missing value of ' country_of_citizenship ' is :- 19272
#  the missing value of ' country_of_citzenship ' is :- 327940
#  the missing value of ' decision_date ' is :- 0
#  the missing value of ' employer_address_1 ' is :- 37
#  the missing value of ' employer_address_2 ' is :- 230365
#  the missing value of ' employer_city ' is :- 10
#  the missing value of ' employer_country ' is :- 126920
#  the missing value of ' employer_decl_info_title ' is :- 126886
#  the missing value of ' employer_name ' is :- 8
#  the missing value of ' employer_num_employees ' is :- 126921
#  the missing value of ' employer_phone ' is :- 126882
#  the missing value of ' employer_phone_ext ' is :- 325683
#  the missing value of ' employer_postal_code ' is :- 33
#  the missing value of ' employer_state ' is :- 37
#  the missing value of ' employer_yr_estab ' is :- 126978
#  the missing value of ' foreign_worker_info_alt_edu_experience ' is :- 262872
#  the missing value of ' foreign_worker_info_birth_country ' is :- 262869
#  the missing value of ' foreign_worker_info_city ' is :- 126873
#  the missing value of ' foreign_worker_info_education ' is :- 142682
#  the missing value of ' foreign_worker_info_education_other ' is :- 343410
#  the missing value of ' foreign_worker_info_inst ' is :- 143001
#  the missing value of ' foreign_worker_info_major ' is :- 143863
#  the missing value of ' foreign_worker_info_postal_code ' is :- 265414
#  the missing value of ' foreign_worker_info_rel_occup_exp ' is :- 262864
#  the missing value of ' foreign_worker_info_req_experience ' is :- 262862
#  the missing value of ' foreign_worker_info_state ' is :- 141633
#  the missing value of ' foreign_worker_info_training_comp ' is :- 262863
#  the missing value of ' foreign_worker_ownership_interest ' is :- 262859
#  the missing value of ' foreign_worker_yr_rel_edu_completed ' is :- 267724
#  the missing value of ' fw_info_alt_edu_experience ' is :- 211155
#  the missing value of ' fw_info_birth_country ' is :- 211167
#  the missing value of ' fw_info_education_other ' is :- 341444
#  the missing value of ' fw_info_postal_code ' is :- 213253
#  the missing value of ' fw_info_rel_occup_exp ' is :- 211158
#  the missing value of ' fw_info_req_experience ' is :- 211154
#  the missing value of ' fw_info_training_comp ' is :- 211157
#  the missing value of ' fw_info_yr_rel_edu_completed ' is :- 222257
#  the missing value of ' fw_ownership_interest ' is :- 211155
#  the missing value of ' ji_foreign_worker_live_on_premises ' is :- 262860
#  the missing value of ' ji_fw_live_on_premises ' is :- 211153
#  the missing value of ' ji_live_in_dom_svc_contract ' is :- 344911
#  the missing value of ' ji_live_in_domestic_service ' is :- 126859
#  the missing value of ' ji_offered_to_sec_j_foreign_worker ' is :- 262860
#  the missing value of ' ji_offered_to_sec_j_fw ' is :- 211153
#  the missing value of ' job_info_alt_cmb_ed_oth_yrs ' is :- 281992
#  the missing value of ' job_info_alt_combo_ed ' is :- 283682
#  the missing value of ' job_info_alt_combo_ed_exp ' is :- 126881
#  the missing value of ' job_info_alt_combo_ed_other ' is :- 338473
#  the missing value of ' job_info_alt_field ' is :- 126880
#  the missing value of ' job_info_alt_field_name ' is :- 260384
#  the missing value of ' job_info_alt_occ ' is :- 207646
#  the missing value of ' job_info_alt_occ_job_title ' is :- 210647
#  the missing value of ' job_info_alt_occ_num_months ' is :- 210841
#  the missing value of ' job_info_combo_occupation ' is :- 126856
#  the missing value of ' job_info_education ' is :- 146630
#  the missing value of ' job_info_education_other ' is :- 340035
#  the missing value of ' job_info_experience ' is :- 126858
#  the missing value of ' job_info_experience_num_months ' is :- 223105
#  the missing value of ' job_info_foreign_ed ' is :- 127073
#  the missing value of ' job_info_foreign_lang_req ' is :- 126863
#  the missing value of ' job_info_job_req_normal ' is :- 126860
#  the missing value of ' job_info_job_title ' is :- 126890
#  the missing value of ' job_info_major ' is :- 150021
#  the missing value of ' job_info_training ' is :- 126862
#  the missing value of ' job_info_training_field ' is :- 343025
#  the missing value of ' job_info_training_num_months ' is :- 342757
#  the missing value of ' job_info_work_city ' is :- 93
#  the missing value of ' job_info_work_postal_code ' is :- 126927
#  the missing value of ' job_info_work_state ' is :- 94
#  the missing value of ' naics_2007_us_code ' is :- 327998
#  the missing value of ' naics_2007_us_title ' is :- 328587
#  the missing value of ' naics_code ' is :- 263059
#  the missing value of ' naics_title ' is :- 263059
#  the missing value of ' naics_us_code ' is :- 211458
#  the missing value of ' naics_us_code_2007 ' is :- 239910
#  the missing value of ' naics_us_title ' is :- 211458
#  the missing value of ' naics_us_title_2007 ' is :- 242882
#  the missing value of ' orig_case_no ' is :- 346901
#  the missing value of ' orig_file_date ' is :- 346913
#  the missing value of ' preparer_info_emp_completed ' is :- 126885
#  the missing value of ' preparer_info_title ' is :- 153949
#  the missing value of ' pw_amount_9089 ' is :- 2199
#  the missing value of ' pw_determ_date ' is :- 127150
#  the missing value of ' pw_expire_date ' is :- 127229
#  the missing value of ' pw_job_title_908 ' is :- 211217
#  the missing value of ' pw_job_title_9089 ' is :- 136323
#  the missing value of ' pw_level_9089 ' is :- 25900
#  the missing value of ' pw_soc_code ' is :- 568
#  the missing value of ' pw_soc_title ' is :- 2315
#  the missing value of ' pw_source_name_9089 ' is :- 2082
#  the missing value of ' pw_source_name_other_9089 ' is :- 332583
#  the missing value of ' pw_track_num ' is :- 128629
#  the missing value of ' pw_unit_of_pay_9089 ' is :- 1479
#  the missing value of ' rec_info_barg_rep_notified ' is :- 262919
#  the missing value of ' recr_info_barg_rep_notified ' is :- 211165
#  the missing value of ' recr_info_coll_teach_comp_proc ' is :- 340583
#  the missing value of ' recr_info_coll_univ_teacher ' is :- 126876
#  the missing value of ' recr_info_employer_rec_payment ' is :- 126865
#  the missing value of ' recr_info_first_ad_start ' is :- 132631
#  the missing value of ' recr_info_job_fair_from ' is :- 345512
#  the missing value of ' recr_info_job_fair_to ' is :- 345516
#  the missing value of ' recr_info_on_campus_recr_from ' is :- 345447
#  the missing value of ' recr_info_on_campus_recr_to ' is :- 345454
#  the missing value of ' recr_info_pro_org_advert_from ' is :- 333862
#  the missing value of ' recr_info_pro_org_advert_to ' is :- 333868
#  the missing value of ' recr_info_prof_org_advert_from ' is :- 321138
#  the missing value of ' recr_info_prof_org_advert_to ' is :- 321145
#  the missing value of ' recr_info_professional_occ ' is :- 126862
#  the missing value of ' recr_info_radio_tv_ad_from ' is :- 328552
#  the missing value of ' recr_info_radio_tv_ad_to ' is :- 328551
#  the missing value of ' recr_info_second_ad_start ' is :- 132666
#  the missing value of ' recr_info_sunday_newspaper ' is :- 132542
#  the missing value of ' recr_info_swa_job_order_end ' is :- 132665
#  the missing value of ' recr_info_swa_job_order_start ' is :- 132643
#  the missing value of ' refile ' is :- 247862
#  the missing value of ' ri_1st_ad_newspaper_name ' is :- 132622
#  the missing value of ' ri_2nd_ad_newspaper_name ' is :- 132682
#  the missing value of ' ri_2nd_ad_newspaper_or_journal ' is :- 132648
#  the missing value of ' ri_campus_placement_from ' is :- 319493
#  the missing value of ' ri_campus_placement_to ' is :- 319503
#  the missing value of ' ri_coll_tch_basic_process ' is :- 340591
#  the missing value of ' ri_coll_teach_pro_jnl ' is :- 341781
#  the missing value of ' ri_coll_teach_select_date ' is :- 341782
#  the missing value of ' ri_employee_referral_prog_from ' is :- 283457
#  the missing value of ' ri_employee_referral_prog_to ' is :- 283455
#  the missing value of ' ri_employer_web_post_from ' is :- 220101
#  the missing value of ' ri_employer_web_post_to ' is :- 220125
#  the missing value of ' ri_job_search_website_from ' is :- 164644
#  the missing value of ' ri_job_search_website_to ' is :- 164656
#  the missing value of ' ri_layoff_in_past_six_months ' is :- 126878
#  the missing value of ' ri_local_ethnic_paper_from ' is :- 235612
#  the missing value of ' ri_local_ethnic_paper_to ' is :- 235611
#  the missing value of ' ri_posted_notice_at_worksite ' is :- 126927
#  the missing value of ' ri_pvt_employment_firm_from ' is :- 331380
#  the missing value of ' ri_pvt_employment_firm_to ' is :- 331382
#  the missing value of ' ri_us_workers_considered ' is :- 331101
#  the missing value of ' schd_a_sheepherder ' is :- 126867
#  the missing value of ' us_economic_sector ' is :- 226289
#  the missing value of ' wage_offer_from_9089 ' is :- 107703
#  the missing value of ' wage_offer_to_9089 ' is :- 278873
#  the missing value of ' wage_offer_unit_of_pay_9089 ' is :- 108766
#  the missing value of ' wage_offered_from_9089 ' is :- 239571
#  the missing value of ' wage_offered_to_9089 ' is :- 317841
#  the missing value of ' wage_offered_unit_of_pay_9089 ' is :- 280459
#  the missing value of ' case_numbers ' is :- 0

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_us_workers_considered', 'schd_a_sheepherder', 'us_economic_sector',
#        'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089',
#        'case_numbers'],
#       dtype='object', length=155)

# %%
df["decision_date"]
# Out:
# 0         2012-02-01
# 1         2011-12-21
# 2         2011-12-01
# 3         2011-12-01
# 4         2012-01-26
#              ...
# 365042    2016-11-22
# 365043    2016-11-22
# 365044    2016-11-22
# 365045    2016-11-22
# 365046    2016-11-22
# Name: decision_date, Length: 347157, dtype: object

# %%
df["decision_date"]=pd.to_datetime(df["decision_date"])

# %%
df["year"] = df["decision_date"].dt.year
df["month"] = df["decision_date"].dt.month
df["day"] = df["decision_date"].dt.day

# %%
df["year"]
# Out:
# 0         2012
# 1         2011
# 2         2011
# 3         2011
# 4         2012
#           ...
# 365042    2016
# 365043    2016
# 365044    2016
# 365045    2016
# 365046    2016
# Name: year, Length: 347157, dtype: int32

# %%
df['month']
# Out:
# 0          2
# 1         12
# 2         12
# 3         12
# 4          1
#           ..
# 365042    11
# 365043    11
# 365044    11
# 365045    11
# 365046    11
# Name: month, Length: 347157, dtype: int32

# %%
df['day']
# Out:
# 0          1
# 1         21
# 2          1
# 3          1
# 4         26
#           ..
# 365042    22
# 365043    22
# 365044    22
# 365045    22
# 365046    22
# Name: day, Length: 347157, dtype: int32

# %%
plt.figure(figsize = (15,8))
sns.countplot(x = "year", hue= "case_status",data=df, palette = "muted")
plt.xticks(rotation = 90)
plt.xlabel("Year")
plt.ylabel("No of Counts")
plt.title("Application Certified and Denied as per Year")
plt.show()

# %%
#insights >> most of the visa certifed in 2016
#lowest visa certified in 2011

# %%
df["employer_city"]
# Out:
# 0              NEW YORK
# 1             CARLSTADT
# 2            GLEN ALLEN
# 3              FLUSHING
# 4                ALBANY
#               ...
# 365042    BENTON HARBOR
# 365043          ATLANTA
# 365044           BOSTON
# 365045          DETROIT
# 365046             TROY
# Name: employer_city, Length: 347157, dtype: object

# %%
df["employer_city"].value_counts()
# Out:
# employer_city
# NEW YORK           15613
# COLLEGE STATION    11978
# SANTA CLARA        10271
# SAN JOSE            8816
# REDMOND             8444
#                    ...
# HANCEVILLE             1
# ORISKANY               1
# BARNEGAT LIGHT         1
# LUQUILLO               1
# WALLED LAKE            1
# Name: count, Length: 8196, dtype: int64

# %%
df["employer_city"]= df["employer_city"].str.upper()

# %%
df["employer_city"].value_counts()
# Out:
# employer_city
# NEW YORK           16728
# COLLEGE STATION    11980
# SANTA CLARA        10341
# SAN JOSE            8944
# REDMOND             8460
#                    ...
# NESCONSET              1
# ST GEORGE              1
# VIDOR                  1
# TIOGA                  1
# WALLED LAKE            1
# Name: count, Length: 5732, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(x= "employer_city", data=df, hue = "year", palette = 'husl', order = df.employer_city.value_counts()[:10].index)
plt.xticks(rotation = 90)
plt.xlabel("Employers Cities")
plt.ylabel("counts")
plt.title("employers data of cities with year")
plt.show()

# %%
df["us_economic_sector"]
# Out:
# 0                            IT
# 1         Other Economic Sector
# 2                     Aerospace
# 3         Other Economic Sector
# 4                  Advanced Mfg
#                   ...
# 365042                      NaN
# 365043                      NaN
# 365044                      NaN
# 365045                      NaN
# 365046                      NaN
# Name: us_economic_sector, Length: 347157, dtype: object

# %%
us_economic_counts = {}

for value in df['us_economic_sector'].dropna():
  if value in us_economic_counts:
    us_economic_counts[value] += 1
  else:
    us_economic_counts[value] = 1

us_economic_counts
# Out:
# {'IT': 49311,
#  'Other Economic Sector': 14662,
#  'Aerospace': 3917,
#  'Advanced Mfg': 17601,
#  'Educational Services': 8561,
#  'Retail': 4208,
#  'Construction': 1315,
#  'Hospitality': 1767,
#  'Automotive': 1084,
#  'Health Care': 6407,
#  'Agribusiness': 784,
#  'Finance': 8686,
#  'Energy': 1021,
#  'Transportation': 893,
#  'Homeland Security': 78,
#  'Biotechnology': 436,
#  'Geospatial': 137}

# %%
us_economic_count =[]
us_economic_label = []

for key,value in us_economic_counts.items():
  us_economic_count.append(key)
  us_economic_label.append(value)

# %%
us_economic_count
# Out:
# ['IT',
#  'Other Economic Sector',
#  'Aerospace',
#  'Advanced Mfg',
#  'Educational Services',
#  'Retail',
#  'Construction',
#  'Hospitality',
#  'Automotive',
#  'Health Care',
#  'Agribusiness',
#  'Finance',
#  'Energy',
#  'Transportation',
#  'Homeland Security',
#  'Biotechnology',
#  'Geospatial']

# %%
us_economic_label
# Out:
# [49311,
#  14662,
#  3917,
#  17601,
#  8561,
#  4208,
#  1315,
#  1767,
#  1084,
#  6407,
#  784,
#  8686,
#  1021,
#  893,
#  78,
#  436,
#  137]

# %%
plt.figure(figsize=(15,8))
plt.pie(us_economic_label[:10], labels = us_economic_count[:10], autopct = "%1.1f%%", explode = [0.1,0.01,0.,0.,0.,0.,0.,0.,0.,0.], shadow=True)
plt.show()

# %%
#top 10 employers via visa application
df["employer_name"]
# Out:
# 0                    NETSOFT USA INC.
# 1         PINNACLE ENVIRONEMNTAL CORP
# 2          SCHNABEL ENGINEERING, INC.
# 3             EBENEZER MISSION CHURCH
# 4          ALBANY INTERNATIONAL CORP.
#                      ...
# 365042          WHIRLPOOL CORPORATION
# 365043     MANHATTAN ASSOCIATES, INC.
# 365044                        FMR LLC
# 365045         GENERAL MOTORS COMPANY
# 365046      HTC GLOBAL SERVICES, INC.
# Name: employer_name, Length: 347157, dtype: object

# %%
top_emp = df['employer_name'].value_counts()[:10]
top_emp
# Out:
# employer_name
# COGNIZANT TECHNOLOGY SOLUTIONS US CORPORATION    11933
# MICROSOFT CORPORATION                             8066
# INTEL CORPORATION                                 6036
# GOOGLE INC.                                       4811
# AMAZON CORPORATE LLC                              3527
# CISCO SYSTEMS, INC.                               2542
# INFOSYS LTD.                                      2497
# APPLE INC.                                        2477
# ORACLE AMERICA, INC.                              2454
# DELOITTE CONSULTING LLP                           1644
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
top_emp.plot(kind = "bar", color = sns.color_palette("muted") )
for i,v in enumerate(top_emp):
  plt.text(i,v+10,str(v),ha = "center", va = "bottom", fontsize = 10 )
plt.show()

# %%
df["job_info_job_title"]
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#                                ...
# 365042    Global Electronics Hardware Architecture Leader
# 365043               Senior Software Engineer, R&D, SCOPE
# 365044                  Principal Technology Risk Analyst
# 365045                                       CAE Engineer
# 365046                                                NaN
# Name: job_info_job_title, Length: 347157, dtype: object

# %%
df["job_info_job_title"].value_counts()[:10]
# Out:
# job_info_job_title
# Software Engineer                   13769
# Computer Systems Analyst - V         4746
# Senior Software Engineer             3659
# Computer Systems Analyst - II        3415
# Software Developer                   2748
# Assistant Professor                  2538
# Computer Systems Analyst - IV        2495
# Programmer Analyst                   2411
# Systems Analyst                      1967
# Software Development Engineer II     1583
# Name: count, dtype: int64

# %%
#Converting values to lower case
df['job_info_job_title'] = df['job_info_job_title'].str.lower()

#Splitting job titles by '-'
df['job_info_job_title'] = df['job_info_job_title'].astype(str).str.split('-').str[0]
#Splitting job titles by 'ii'
df['job_info_job_title'] = df['job_info_job_title'].astype(str).str.split('ii').str[0]
#Splitting job titles by '/'
df['job_info_job_title'] = df['job_info_job_title'].astype(str).str.split('/').str[0]
#Removing leading and ending spaces
df['job_info_job_title'] = df['job_info_job_title'].astype(str).str.strip()
#Replacing "sr." values with "senior"
df['job_info_job_title'] = df['job_info_job_title'].str.replace('sr.', 'senior')
#Replacing "NaN", "NaT" and "nan" values with np.nan
df['job_info_job_title'].replace(["NaN", 'NaT','nan'], np.nan, inplace = True)


df['job_info_job_title'].value_counts(dropna=True)[:10]
# Out:
# job_info_job_title
# software engineer                17857
# computer systems analyst         12023
# senior software engineer          5603
# software developer                4295
# programmer analyst                3591
# assistant professor               2794
# software development engineer     2686
# systems analyst                   2493
# senior programmer analyst         1808
# senior software developer         1545
# Name: count, dtype: int64

# %%
top_job_titles = df['job_info_job_title'].value_counts(dropna=True)[:10]

plt.figure(figsize=(15,8))
plt.bar( top_job_titles.index, top_job_titles, color = sns.color_palette("husl"))

for i,v in enumerate(top_job_titles):
  plt.text(i,v+10, str(v), ha = "center", va = "bottom", fontsize = 10,)


plt.title("top 10 job titles")
plt.xlabel("job_title via visa application")
plt.ylabel("No of visa applicant")
plt.xticks(rotation = 90)
plt.show()

# %%
df["country_of_citizenship"] = pd.Categorical(df["country_of_citizenship"])
df["country_of_citizenship"]
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#            ...
# 365042    BRAZIL
# 365043     INDIA
# 365044     CHINA
# 365045     INDIA
# 365046     INDIA
# Name: country_of_citizenship, Length: 347157, dtype: category
# Categories (201, object): ['AFGHANISTAN', 'ALBANIA', 'ALGERIA', 'ANDORRA', ..., 'YEMEN', 'YUGOSLAVIA',
#                            'ZAMBIA', 'ZIMBABWE']

# %%
top_citizenship = df["country_of_citizenship"].value_counts().iloc[:10]

# %%
plt.figure(figsize=(15,8))




sns.countplot(x = "country_of_citizenship",data=df,order = top_citizenship.index ,palette = "husl")
for i,v in enumerate(top_citizenship):
  plt.text(i,v+10, str(v), ha = "center", va = "bottom", fontsize = 10,)



plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,8))




sns.countplot(x = "country_of_citizenship",data=df,hue ="case_status", order = top_citizenship.index ,palette = "coolwarm")



plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,8))

sns.countplot(x = "application_type",data=df,order = df["application_type"].value_counts().iloc[:10].index ,palette = "husl")
for i,v in enumerate(df["application_type"].value_counts()[:10]):
  plt.text(i,v+10, str(v), ha = "center", va = "bottom", fontsize = 10,)

plt.xticks(rotation = 90)
plt.xlabel('Application type')
plt.ylabel('Number of Visa applications')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x = "foreign_worker_info_education", data = df, palette = "muted",order=df['foreign_worker_info_education'].value_counts().index[:10])

for i,v in enumerate(df['foreign_worker_info_education'].value_counts().head(10)):
  plt.text(i, v+10,str(v) ,ha = "center",va= "bottom" , fontsize=10)

plt.xticks(rotation = 90)
plt.xlabel("Education level")
plt.ylabel("Number of Visa applications")
plt.show()

# %%
for values in df.columns:
  print(f"{values}, contain the {df[values].isna().sum()} values")
# Out:
# add_these_pw_job_title_9089, contain the 308020 values
# agent_city, contain the 152842 values
# agent_firm_name, contain the 156873 values
# agent_state, contain the 155815 values
# application_type, contain the 220309 values
# case_no, contain the 220309 values
# case_number, contain the 126848 values
# case_received_date, contain the 126848 values
# case_status, contain the 0 values
# class_of_admission, contain the 20368 values
# country_of_citizenship, contain the 19272 values
# country_of_citzenship, contain the 327940 values
# decision_date, contain the 0 values
# employer_address_1, contain the 37 values
# employer_address_2, contain the 230365 values
# employer_city, contain the 10 values
# employer_country, contain the 126920 values
# employer_decl_info_title, contain the 126886 values
# employer_name, contain the 8 values
# employer_num_employees, contain the 126921 values
# employer_phone, contain the 126882 values
# employer_phone_ext, contain the 325683 values
# employer_postal_code, contain the 33 values
# employer_state, contain the 37 values
# employer_yr_estab, contain the 126978 values
# foreign_worker_info_alt_edu_experience, contain the 262872 values
# foreign_worker_info_birth_country, contain the 262869 values
# foreign_worker_info_city, contain the 126873 values
# foreign_worker_info_education, contain the 142682 values
# foreign_worker_info_education_other, contain the 343410 values
# foreign_worker_info_inst, contain the 143001 values
# foreign_worker_info_major, contain the 143863 values
# foreign_worker_info_postal_code, contain the 265414 values
# foreign_worker_info_rel_occup_exp, contain the 262864 values
# foreign_worker_info_req_experience, contain the 262862 values
# foreign_worker_info_state, contain the 141633 values
# foreign_worker_info_training_comp, contain the 262863 values
# foreign_worker_ownership_interest, contain the 262859 values
# foreign_worker_yr_rel_edu_completed, contain the 267724 values
# fw_info_alt_edu_experience, contain the 211155 values
# fw_info_birth_country, contain the 211167 values
# fw_info_education_other, contain the 341444 values
# fw_info_postal_code, contain the 213253 values
# fw_info_rel_occup_exp, contain the 211158 values
# fw_info_req_experience, contain the 211154 values
# fw_info_training_comp, contain the 211157 values
# fw_info_yr_rel_edu_completed, contain the 222257 values
# fw_ownership_interest, contain the 211155 values
# ji_foreign_worker_live_on_premises, contain the 262860 values
# ji_fw_live_on_premises, contain the 211153 values
# ji_live_in_dom_svc_contract, contain the 344911 values
# ji_live_in_domestic_service, contain the 126859 values
# ji_offered_to_sec_j_foreign_worker, contain the 262860 values
# ji_offered_to_sec_j_fw, contain the 211153 values
# job_info_alt_cmb_ed_oth_yrs, contain the 281992 values
# job_info_alt_combo_ed, contain the 283682 values
# job_info_alt_combo_ed_exp, contain the 126881 values
# job_info_alt_combo_ed_other, contain the 338473 values
# job_info_alt_field, contain the 126880 values
# job_info_alt_field_name, contain the 260384 values
# job_info_alt_occ, contain the 207646 values
# job_info_alt_occ_job_title, contain the 210647 values
# job_info_alt_occ_num_months, contain the 210841 values
# job_info_combo_occupation, contain the 126856 values
# job_info_education, contain the 146630 values
# job_info_education_other, contain the 340035 values
# job_info_experience, contain the 126858 values
# job_info_experience_num_months, contain the 223105 values
# job_info_foreign_ed, contain the 127073 values
# job_info_foreign_lang_req, contain the 126863 values
# job_info_job_req_normal, contain the 126860 values
# job_info_job_title, contain the 126890 values
# job_info_major, contain the 150021 values
# job_info_training, contain the 126862 values
# job_info_training_field, contain the 343025 values
# job_info_training_num_months, contain the 342757 values
# job_info_work_city, contain the 93 values
# job_info_work_postal_code, contain the 126927 values
# job_info_work_state, contain the 94 values
# naics_2007_us_code, contain the 327998 values
# naics_2007_us_title, contain the 328587 values
# naics_code, contain the 263059 values
# naics_title, contain the 263059 values
# naics_us_code, contain the 211458 values
# naics_us_code_2007, contain the 239910 values
# naics_us_title, contain the 211458 values
# naics_us_title_2007, contain the 242882 values
# orig_case_no, contain the 346901 values
# orig_file_date, contain the 346913 values
# preparer_info_emp_completed, contain the 126885 values
# preparer_info_title, contain the 153949 values
# pw_amount_9089, contain the 2199 values
# pw_determ_date, contain the 127150 values
# pw_expire_date, contain the 127229 values
# pw_job_title_908, contain the 211217 values
# pw_job_title_9089, contain the 136323 values
# pw_level_9089, contain the 25900 values
# pw_soc_code, contain the 568 values
# pw_soc_title, contain the 2315 values
# pw_source_name_9089, contain the 2082 values
# pw_source_name_other_9089, contain the 332583 values
# pw_track_num, contain the 128629 values
# pw_unit_of_pay_9089, contain the 1479 values
# rec_info_barg_rep_notified, contain the 262919 values
# recr_info_barg_rep_notified, contain the 211165 values
# recr_info_coll_teach_comp_proc, contain the 340583 values
# recr_info_coll_univ_teacher, contain the 126876 values
# recr_info_employer_rec_payment, contain the 126865 values
# recr_info_first_ad_start, contain the 132631 values
# recr_info_job_fair_from, contain the 345512 values
# recr_info_job_fair_to, contain the 345516 values
# recr_info_on_campus_recr_from, contain the 345447 values
# recr_info_on_campus_recr_to, contain the 345454 values
# recr_info_pro_org_advert_from, contain the 333862 values
# recr_info_pro_org_advert_to, contain the 333868 values
# recr_info_prof_org_advert_from, contain the 321138 values
# recr_info_prof_org_advert_to, contain the 321145 values
# recr_info_professional_occ, contain the 126862 values
# recr_info_radio_tv_ad_from, contain the 328552 values
# recr_info_radio_tv_ad_to, contain the 328551 values
# recr_info_second_ad_start, contain the 132666 values
# recr_info_sunday_newspaper, contain the 132542 values
# recr_info_swa_job_order_end, contain the 132665 values
# recr_info_swa_job_order_start, contain the 132643 values
# refile, contain the 247862 values
# ri_1st_ad_newspaper_name, contain the 132622 values
# ri_2nd_ad_newspaper_name, contain the 132682 values
# ri_2nd_ad_newspaper_or_journal, contain the 132648 values
# ri_campus_placement_from, contain the 319493 values
# ri_campus_placement_to, contain the 319503 values
# ri_coll_tch_basic_process, contain the 340591 values
# ri_coll_teach_pro_jnl, contain the 341781 values
# ri_coll_teach_select_date, contain the 341782 values
# ri_employee_referral_prog_from, contain the 283457 values
# ri_employee_referral_prog_to, contain the 283455 values
# ri_employer_web_post_from, contain the 220101 values
# ri_employer_web_post_to, contain the 220125 values
# ri_job_search_website_from, contain the 164644 values
# ri_job_search_website_to, contain the 164656 values
# ri_layoff_in_past_six_months, contain the 126878 values
# ri_local_ethnic_paper_from, contain the 235612 values
# ri_local_ethnic_paper_to, contain the 235611 values
# ri_posted_notice_at_worksite, contain the 126927 values
# ri_pvt_employment_firm_from, contain the 331380 values
# ri_pvt_employment_firm_to, contain the 331382 values
# ri_us_workers_considered, contain the 331101 values
# schd_a_sheepherder, contain the 126867 values
# us_economic_sector, contain the 226289 values
# wage_offer_from_9089, contain the 107703 values
# wage_offer_to_9089, contain the 278873 values
# wage_offer_unit_of_pay_9089, contain the 108766 values
# wage_offered_from_9089, contain the 239571 values
# wage_offered_to_9089, contain the 317841 values
# wage_offered_unit_of_pay_9089, contain the 280459 values
# case_numbers, contain the 0 values
# year, contain the 0 values
# month, contain the 0 values
# day, contain the 0 values

# %%
i = 0
for col in df.columns:
  i +=1
  print(i-1,"column :", f" ''{col}'' contains {round((df[col].count()/len(df.case_status))*100, 2)}% missing values")
# Out:
# 0 column :  ''add_these_pw_job_title_9089'' contains 11.27% missing values
# 1 column :  ''agent_city'' contains 55.97% missing values
# 2 column :  ''agent_firm_name'' contains 54.81% missing values
# 3 column :  ''agent_state'' contains 55.12% missing values
# 4 column :  ''application_type'' contains 36.54% missing values
# 5 column :  ''case_no'' contains 36.54% missing values
# 6 column :  ''case_number'' contains 63.46% missing values
# 7 column :  ''case_received_date'' contains 63.46% missing values
# 8 column :  ''case_status'' contains 100.0% missing values
# 9 column :  ''class_of_admission'' contains 94.13% missing values
# 10 column :  ''country_of_citizenship'' contains 94.45% missing values
# 11 column :  ''country_of_citzenship'' contains 5.54% missing values
# 12 column :  ''decision_date'' contains 100.0% missing values
# 13 column :  ''employer_address_1'' contains 99.99% missing values
# 14 column :  ''employer_address_2'' contains 33.64% missing values
# 15 column :  ''employer_city'' contains 100.0% missing values
# 16 column :  ''employer_country'' contains 63.44% missing values
# 17 column :  ''employer_decl_info_title'' contains 63.45% missing values
# 18 column :  ''employer_name'' contains 100.0% missing values
# 19 column :  ''employer_num_employees'' contains 63.44% missing values
# 20 column :  ''employer_phone'' contains 63.45% missing values
# 21 column :  ''employer_phone_ext'' contains 6.19% missing values
# 22 column :  ''employer_postal_code'' contains 99.99% missing values
# 23 column :  ''employer_state'' contains 99.99% missing values
# 24 column :  ''employer_yr_estab'' contains 63.42% missing values
# 25 column :  ''foreign_worker_info_alt_edu_experience'' contains 24.28% missing values
# 26 column :  ''foreign_worker_info_birth_country'' contains 24.28% missing values
# 27 column :  ''foreign_worker_info_city'' contains 63.45% missing values
# 28 column :  ''foreign_worker_info_education'' contains 58.9% missing values
# 29 column :  ''foreign_worker_info_education_other'' contains 1.08% missing values
# 30 column :  ''foreign_worker_info_inst'' contains 58.81% missing values
# 31 column :  ''foreign_worker_info_major'' contains 58.56% missing values
# 32 column :  ''foreign_worker_info_postal_code'' contains 23.55% missing values
# 33 column :  ''foreign_worker_info_rel_occup_exp'' contains 24.28% missing values
# 34 column :  ''foreign_worker_info_req_experience'' contains 24.28% missing values
# 35 column :  ''foreign_worker_info_state'' contains 59.2% missing values
# 36 column :  ''foreign_worker_info_training_comp'' contains 24.28% missing values
# 37 column :  ''foreign_worker_ownership_interest'' contains 24.28% missing values
# 38 column :  ''foreign_worker_yr_rel_edu_completed'' contains 22.88% missing values
# 39 column :  ''fw_info_alt_edu_experience'' contains 39.18% missing values
# 40 column :  ''fw_info_birth_country'' contains 39.17% missing values
# 41 column :  ''fw_info_education_other'' contains 1.65% missing values
# 42 column :  ''fw_info_postal_code'' contains 38.57% missing values
# 43 column :  ''fw_info_rel_occup_exp'' contains 39.18% missing values
# 44 column :  ''fw_info_req_experience'' contains 39.18% missing values
# 45 column :  ''fw_info_training_comp'' contains 39.18% missing values
# 46 column :  ''fw_info_yr_rel_edu_completed'' contains 35.98% missing values
# 47 column :  ''fw_ownership_interest'' contains 39.18% missing values
# 48 column :  ''ji_foreign_worker_live_on_premises'' contains 24.28% missing values
# 49 column :  ''ji_fw_live_on_premises'' contains 39.18% missing values
# 50 column :  ''ji_live_in_dom_svc_contract'' contains 0.65% missing values
# 51 column :  ''ji_live_in_domestic_service'' contains 63.46% missing values
# 52 column :  ''ji_offered_to_sec_j_foreign_worker'' contains 24.28% missing values
# 53 column :  ''ji_offered_to_sec_j_fw'' contains 39.18% missing values
# 54 column :  ''job_info_alt_cmb_ed_oth_yrs'' contains 18.77% missing values
# 55 column :  ''job_info_alt_combo_ed'' contains 18.28% missing values
# 56 column :  ''job_info_alt_combo_ed_exp'' contains 63.45% missing values
# 57 column :  ''job_info_alt_combo_ed_other'' contains 2.5% missing values
# 58 column :  ''job_info_alt_field'' contains 63.45% missing values
# 59 column :  ''job_info_alt_field_name'' contains 25.0% missing values
# 60 column :  ''job_info_alt_occ'' contains 40.19% missing values
# 61 column :  ''job_info_alt_occ_job_title'' contains 39.32% missing values
# 62 column :  ''job_info_alt_occ_num_months'' contains 39.27% missing values
# 63 column :  ''job_info_combo_occupation'' contains 63.46% missing values
# 64 column :  ''job_info_education'' contains 57.76% missing values
# 65 column :  ''job_info_education_other'' contains 2.05% missing values
# 66 column :  ''job_info_experience'' contains 63.46% missing values
# 67 column :  ''job_info_experience_num_months'' contains 35.73% missing values
# 68 column :  ''job_info_foreign_ed'' contains 63.4% missing values
# 69 column :  ''job_info_foreign_lang_req'' contains 63.46% missing values
# 70 column :  ''job_info_job_req_normal'' contains 63.46% missing values
# 71 column :  ''job_info_job_title'' contains 63.45% missing values
# 72 column :  ''job_info_major'' contains 56.79% missing values
# 73 column :  ''job_info_training'' contains 63.46% missing values
# 74 column :  ''job_info_training_field'' contains 1.19% missing values
# 75 column :  ''job_info_training_num_months'' contains 1.27% missing values
# 76 column :  ''job_info_work_city'' contains 99.97% missing values
# 77 column :  ''job_info_work_postal_code'' contains 63.44% missing values
# 78 column :  ''job_info_work_state'' contains 99.97% missing values
# 79 column :  ''naics_2007_us_code'' contains 5.52% missing values
# 80 column :  ''naics_2007_us_title'' contains 5.35% missing values
# 81 column :  ''naics_code'' contains 24.22% missing values
# 82 column :  ''naics_title'' contains 24.22% missing values
# 83 column :  ''naics_us_code'' contains 39.09% missing values
# 84 column :  ''naics_us_code_2007'' contains 30.89% missing values
# 85 column :  ''naics_us_title'' contains 39.09% missing values
# 86 column :  ''naics_us_title_2007'' contains 30.04% missing values
# 87 column :  ''orig_case_no'' contains 0.07% missing values
# 88 column :  ''orig_file_date'' contains 0.07% missing values
# 89 column :  ''preparer_info_emp_completed'' contains 63.45% missing values
# 90 column :  ''preparer_info_title'' contains 55.65% missing values
# 91 column :  ''pw_amount_9089'' contains 99.37% missing values
# 92 column :  ''pw_determ_date'' contains 63.37% missing values
# 93 column :  ''pw_expire_date'' contains 63.35% missing values
# 94 column :  ''pw_job_title_908'' contains 39.16% missing values
# 95 column :  ''pw_job_title_9089'' contains 60.73% missing values
# 96 column :  ''pw_level_9089'' contains 92.54% missing values
# 97 column :  ''pw_soc_code'' contains 99.84% missing values
# 98 column :  ''pw_soc_title'' contains 99.33% missing values
# 99 column :  ''pw_source_name_9089'' contains 99.4% missing values
# 100 column :  ''pw_source_name_other_9089'' contains 4.2% missing values
# 101 column :  ''pw_track_num'' contains 62.95% missing values
# 102 column :  ''pw_unit_of_pay_9089'' contains 99.57% missing values
# 103 column :  ''rec_info_barg_rep_notified'' contains 24.27% missing values
# 104 column :  ''recr_info_barg_rep_notified'' contains 39.17% missing values
# 105 column :  ''recr_info_coll_teach_comp_proc'' contains 1.89% missing values
# 106 column :  ''recr_info_coll_univ_teacher'' contains 63.45% missing values
# 107 column :  ''recr_info_employer_rec_payment'' contains 63.46% missing values
# 108 column :  ''recr_info_first_ad_start'' contains 61.8% missing values
# 109 column :  ''recr_info_job_fair_from'' contains 0.47% missing values
# 110 column :  ''recr_info_job_fair_to'' contains 0.47% missing values
# 111 column :  ''recr_info_on_campus_recr_from'' contains 0.49% missing values
# 112 column :  ''recr_info_on_campus_recr_to'' contains 0.49% missing values
# 113 column :  ''recr_info_pro_org_advert_from'' contains 3.83% missing values
# 114 column :  ''recr_info_pro_org_advert_to'' contains 3.83% missing values
# 115 column :  ''recr_info_prof_org_advert_from'' contains 7.49% missing values
# 116 column :  ''recr_info_prof_org_advert_to'' contains 7.49% missing values
# 117 column :  ''recr_info_professional_occ'' contains 63.46% missing values
# 118 column :  ''recr_info_radio_tv_ad_from'' contains 5.36% missing values
# 119 column :  ''recr_info_radio_tv_ad_to'' contains 5.36% missing values
# 120 column :  ''recr_info_second_ad_start'' contains 61.79% missing values
# 121 column :  ''recr_info_sunday_newspaper'' contains 61.82% missing values
# 122 column :  ''recr_info_swa_job_order_end'' contains 61.79% missing values
# 123 column :  ''recr_info_swa_job_order_start'' contains 61.79% missing values
# 124 column :  ''refile'' contains 28.6% missing values
# 125 column :  ''ri_1st_ad_newspaper_name'' contains 61.8% missing values
# 126 column :  ''ri_2nd_ad_newspaper_name'' contains 61.78% missing values
# 127 column :  ''ri_2nd_ad_newspaper_or_journal'' contains 61.79% missing values
# 128 column :  ''ri_campus_placement_from'' contains 7.97% missing values
# 129 column :  ''ri_campus_placement_to'' contains 7.97% missing values
# 130 column :  ''ri_coll_tch_basic_process'' contains 1.89% missing values
# 131 column :  ''ri_coll_teach_pro_jnl'' contains 1.55% missing values
# 132 column :  ''ri_coll_teach_select_date'' contains 1.55% missing values
# 133 column :  ''ri_employee_referral_prog_from'' contains 18.35% missing values
# 134 column :  ''ri_employee_referral_prog_to'' contains 18.35% missing values
# 135 column :  ''ri_employer_web_post_from'' contains 36.6% missing values
# 136 column :  ''ri_employer_web_post_to'' contains 36.59% missing values
# 137 column :  ''ri_job_search_website_from'' contains 52.57% missing values
# 138 column :  ''ri_job_search_website_to'' contains 52.57% missing values
# 139 column :  ''ri_layoff_in_past_six_months'' contains 63.45% missing values
# 140 column :  ''ri_local_ethnic_paper_from'' contains 32.13% missing values
# 141 column :  ''ri_local_ethnic_paper_to'' contains 32.13% missing values
# 142 column :  ''ri_posted_notice_at_worksite'' contains 63.44% missing values
# 143 column :  ''ri_pvt_employment_firm_from'' contains 4.54% missing values
# 144 column :  ''ri_pvt_employment_firm_to'' contains 4.54% missing values
# 145 column :  ''ri_us_workers_considered'' contains 4.62% missing values
# 146 column :  ''schd_a_sheepherder'' contains 63.46% missing values
# 147 column :  ''us_economic_sector'' contains 34.82% missing values
# 148 column :  ''wage_offer_from_9089'' contains 68.98% missing values
# 149 column :  ''wage_offer_to_9089'' contains 19.67% missing values
# 150 column :  ''wage_offer_unit_of_pay_9089'' contains 68.67% missing values
# 151 column :  ''wage_offered_from_9089'' contains 30.99% missing values
# 152 column :  ''wage_offered_to_9089'' contains 8.44% missing values
# 153 column :  ''wage_offered_unit_of_pay_9089'' contains 19.21% missing values
# 154 column :  ''case_numbers'' contains 100.0% missing values
# 155 column :  ''year'' contains 100.0% missing values
# 156 column :  ''month'' contains 100.0% missing values
# 157 column :  ''day'' contains 100.0% missing values

# %%
#keep the columns with non null values count > 33000
df = df.loc[:, df.count()>= 330000]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 347157 entries, 0 to 365046
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   case_status           347157 non-null  object
#  1   decision_date         347157 non-null  datetime64[ns]
#  2   employer_address_1    347120 non-null  object
#  3   employer_city         347147 non-null  object
#  4   employer_name         347149 non-null  object
#  5   employer_postal_code  347124 non-null  object
#  6   employer_state        347120 non-null  object
#  7   job_info_work_city    347064 non-null  object
#  8   job_info_work_state   347063 non-null  object
#  9   pw_amount_9089        344958 non-null  object
#  10  pw_soc_code           346589 non-null  object
#  11  pw_soc_title          344842 non-null  object
#  12  pw_source_name_9089   345075 non-null  object
#  13  pw_unit_of_pay_9089   345678 non-null  object
#  14  case_numbers          347157 non-null  object
#  15  year                  347157 non-null  int32
#  16  month                 347157 non-null  int32
#  17  day                   347157 non-null  int32
# dtypes: datetime64[ns](1), int32(3), object(14)
# memory usage: 46.4+ MB

# %%
df.columns
# Out:
# Index(['case_status', 'decision_date', 'employer_address_1', 'employer_city',
#        'employer_name', 'employer_postal_code', 'employer_state',
#        'job_info_work_city', 'job_info_work_state', 'pw_amount_9089',
#        'pw_soc_code', 'pw_soc_title', 'pw_source_name_9089',
#        'pw_unit_of_pay_9089', 'case_numbers', 'year', 'month', 'day'],
#       dtype='object')

# %%
df.loc[df['case_status'] == 'Certified', 'case_status'] =1
df.loc[df['case_status'] == 'Denied', 'case_status'] =0

# %%
df["case_status"].value_counts()
# Out:
# case_status
# 1    322126
# 0     25031
# Name: count, dtype: int64

# %%
df['case_status'].unique()
# Out:
# array([1, 0], dtype=object)

# %%
df["employer_state"]
# Out:
# 0         NY
# 1         NY
# 2         VA
# 3         NY
# 4         NY
#           ..
# 365042    MI
# 365043    GA
# 365044    MA
# 365045    MI
# 365046    MI
# Name: employer_state, Length: 347157, dtype: object

# %%
df["employer_state"].unique()
# Out:
# array(['NY', 'VA', 'FL', 'DE', 'NJ', 'GA', 'MD', 'IL', 'TX', 'KY', 'WY',
#        'OH', 'MS', 'MA', 'NC', 'CA', 'MO', 'CT', 'AZ', 'WI', 'PA', 'WA',
#        'CO', 'MN', 'NV', 'UT', 'AL', 'OK', 'LA', 'RI', 'DC', 'MI', 'IA',
#        'NH', 'IN', 'SD', nan, 'OR', 'NE', 'KS', 'TN', 'PR', 'AR', 'GU',
#        'WV', 'SC', 'ID', 'VI', 'ND', 'HI', 'VT', 'ME', 'NM', 'MP', 'AK',
#        'MT', 'GEORGIA', 'NEW YORK', 'TEXAS', 'CALIFORNIA', 'WASHINGTON',
#        'NEW JERSEY', 'ARIZONA', 'NORTH CAROLINA', 'WISCONSIN',
#        'LOUISIANA', 'MAINE', 'OHIO', 'MARYLAND', 'MASSACHUSETTS',
#        'MICHIGAN', 'ILLINOIS', 'PENNSYLVANIA', 'VERMONT', 'VIRGINIA',
#        'FLORIDA', 'MISSOURI', 'ARKANSAS', 'NEW HAMPSHIRE', 'INDIANA',
#        'OKLAHOMA', 'UTAH', 'CONNECTICUT', 'SOUTH DAKOTA', 'DELAWARE',
#        'ALABAMA', 'WEST VIRGINIA', 'NEBRASKA', 'OREGON', 'COLORADO',
#        'RHODE ISLAND', 'KANSAS', 'ALASKA', 'DISTRICT OF COLUMBIA',
#        'MINNESOTA', 'TENNESSEE', 'KENTUCKY', 'GUAM', 'IOWA', 'NEW MEXICO',
#        'NORTH DAKOTA', 'NEVADA', 'MISSISSIPPI', 'IDAHO', 'PUERTO RICO',
#        'SOUTH CAROLINA', 'VIRGIN ISLANDS', 'MONTANA', 'HAWAII', 'WYOMING',
#        'NORTHERN MARIANA ISLANDS', 'MARSHALL ISLANDS', 'BRITISH COLUMBIA',
#        'BC'], dtype=object)

# %%
df["employer_state"].isnull().sum()
# Out:
# 37

# %%
df["employer_state"] = df["employer_state"].fillna(df["employer_state"].mode()[0])

# %%
df["employer_state"].isnull().sum()
# Out:
# 0

# %%
#Mapping from state name to abbreviation
state_abbrevs = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
    'Northern Mariana Islands':'MP',
    'Palau': 'PW',
    'Puerto Rico': 'PR',
    'Virgin Islands': 'VI',
    'District of Columbia': 'DC'
}

#Capitalizing Keys
us_state_abbrev = {k.upper(): v for k, v in state_abbrevs.items()}
df['employer_state'].replace(us_state_abbrev, inplace=True)
df.employer_state = df.employer_state.astype(str)

# %%
df['pw_soc_code']
# Out:
# 0         15-1031.00
# 1         47-4041.00
# 2         17-2051.00
# 3         43-4071.00
# 4         41-9031.00
#              ...
# 365042       11-9041
# 365043       15-1132
# 365044       15-1122
# 365045       17-2141
# 365046           NaN
# Name: pw_soc_code, Length: 347157, dtype: object

# %%
df['pw_soc_code'] = df['pw_soc_code'].str.replace('-' , "")
df['pw_soc_code'] = df['pw_soc_code'].str.replace('.',"")
df['pw_soc_code'] = df['pw_soc_code'].astype(str).str[0:6]
df['pw_soc_code'].value_counts()
# Out:
# pw_soc_code
# 151132    107709
# 151121     31871
# 151133     19919
# 172072     12301
# 113021      7371
#            ...
# 292053         1
# 519032         1
# 193093         1
# 434199         1
# 515022         1
# Name: count, Length: 769, dtype: int64

# %%
df['pw_soc_code'].unique()
# Out:
# array(['151031', '474041', '172051', '434071', '419031', '252031',
#        '131051', '151051', '411011', '273031', '173023', '151081',
#        '519041', '472141', '412031', '513011', '514121', '119041',
#        '119081', '351011', '172081', '475012', '352014', '152031',
#        '472031', '451011', '172072', '414012', '352011', '373011',
#        '372011', '399099', '436011', '193021', '472021', '292011',
#        '452093', '252021', '471011', '113021', '151011', '452091',
#        '151032', 'nan', '414011', '291063', '132011', '352021', '172161',
#        '472022', '372012', '132041', '351012', '311012', '112022',
#        '172141', '111011', '119051', '271021', '119111', '433031',
#        '132051', '499021', '472061', '474071', '113061', '499042',
#        '151099', '192031', '271011', '151071', '472221', '474099',
#        '113011', '113031', '517011', '472181', '399021', '211021',
#        '291011', '111021', '252011', '252022', '291127', '271014',
#        '413031', '172112', '173012', '291122', '472044', '251011',
#        '112021', '172071', '291051', '472073', '439011', '252043',
#        '112031', '151061', '211023', '251124', '272041', '472152',
#        '172061', '271029', '251121', '352013', '273022', '474031',
#        '152041', '291199', '311011', '131022', '119033', '252012',
#        '151021', '251052', '193051', '131111', '259031', '492098',
#        '399011', '173011', '251054', '192012', '511011', '493023',
#        '472151', '232011', '131073', '499043', '472051', '191029',
#        '493042', '252042', '119012', '291065', '431011', '491011',
#        '171011', '273091', '492092', '435081', '473013', '413099',
#        '131199', '413041', '132031', '259099', '211011', '194092',
#        '119151', '191021', '472211', '191042', '191011', '436014',
#        '192021', '434151', '516052', '192043', '359031', '231011',
#        '212021', '519061', '131081', '271023', '291071', '251193',
#        '172121', '352019', '172041', '531031', '493031', '516092',
#        '412011', '151034', '436013', '533032', '472041', '435061',
#        '536021', '433061', '513021', '252041', '514021', '452021',
#        '291064', '519071', '291131', '299011', '291023', '172151',
#        '371011', '371012', '271024', '119199', '291021', '251032',
#        '172131', '395012', '253021', '254021', '373013', '516093',
#        '119121', '353041', '251022', '251021', '132072', '251071',
#        '251042', '253099', '472161', '113042', '119032', '172021',
#        '434131', '537064', '391021', '193011', '435071', '113041',
#        '251081', '399041', '119031', '291062', '131072', '172011',
#        '472111', '514012', '399031', '319091', '519122', '395092',
#        '211012', '251063', '392021', '513022', '433021', '172031',
#        '151041', '191023', '272022', '291031', '271025', '373019',
#        '211091', '194061', '171012', '319092', '434051', '173027',
#        '173026', '171022', '112011', '473012', '515023', '251112',
#        '251125', '339092', '119011', '411012', '272012', '439061',
#        '211015', '273042', '312022', '419022', '212011', '193094',
#        '291069', '192042', '474091', '191012', '452092', '499098',
#        '493099', '193032', '152011', '251113', '273041', '173024',
#        '132052', '173029', '493021', '537032', '434081', '251111',
#        '352015', '516031', '251123', '251064', '271022', '113071',
#        '499061', '193092', '192041', '131071', '192032', '212099',
#        '353031', '519195', '516011', '514034', '434161', '113049',
#        '119021', '259011', '131031', '536031', '514033', '119141',
#        '292033', '413011', '113051', '519123', '232092', '372021',
#        '132099', '251041', '535021', '531021', '473015', '251122',
#        '152021', '291061', '252032', '312021', '291067', '132061',
#        '251072', '537051', '537061', '396021', '291081', '131032',
#        '273043', '131041', '433051', '493041', '172199', '193031',
#        '395094', '292061', '352012', '434141', '533031', '131021',
#        '536051', '173022', '274032', '253011', '473019', '519081',
#        '519121', '499011', '211013', '514031', '251051', '292032',
#        '251031', '131023', '353022', '211099', '259021', '517032',
#        '193022', '251065', '271013', '533033', '191013', '291066',
#        '292052', '194021', '291041', '211093', '251199', '251194',
#        '499063', '516051', '537062', '251126', '172111', '519111',
#        '499052', '514111', '419021', '151022', '172171', '514035',
#        '499041', '493093', '392011', '251082', '473011', '519011',
#        '211014', '499031', '519022', '191022', '191041', '353021',
#        '251066', '492022', '517021', '254011', '151035', '211022',
#        '299091', '173021', '512011', '251061', '291123', '132071',
#        '251062', '251067', '193099', '173031', '211019', '492094',
#        '251043', '514192', '251191', '152091', '493053', '172075',
#        '499091', '251069', '291125', '254012', '171021', '251053',
#        '251192', '271026', '131121', '151052', '472042', '373012',
#        '132053', '272042', '194041', '292034', '319096', '512041',
#        '193039', '292055', '518012', '436012', '519082', '274012',
#        '291029', '439031', '151036', '151037', '194031', '172144',
#        '513092', '292081', '194091', '172076', '172143', '434031',
#        '191002', '512023', '193091', '173013', '131079', '113040',
#        '399032', '292012', '172073', '419099', '291020', '452099',
#        '493011', '151133', '151121', '151132', '519199', '519083',
#        '472081', '517099', '151179', '516021', '151131', '131161',
#        '151111', '151150', '151141', '131078', '151142', '131151',
#        '514081', '499093', '193041', '413021', '292021', '514193',
#        '151799', '151023', '272032', '514041', '434181', '119161',
#        '512031', '519198', '473014', '291181', '512099', '412021',
#        '439081', '473016', '499071', '272021', '132021', '397012',
#        '252054', '131011', '274014', '172053', '514191', '252053',
#        '515113', '499062', '119013', '292071', '532012', '173019',
#        '519193', '394021', '231012', '113121', '274031', '433011',
#        '319011', '499064', '472071', '492011', '131141', '537072',
#        '172074', '113131', '492096', '435011', '271027', '291024',
#        '291022', '194011', '119039', '292799', '514122', '211029',
#        '152099', '372019', '273021', '434171', '273011', '291124',
#        '533041', '435111', '194099', '151053', '513023', '232099',
#        '231022', '274021', '173025', '271019', '113111', '259041',
#        '419041', '514023', '513093', '514051', '514072', '274011',
#        '514071', '518021', '359021', '475021', '435031', '499044',
#        '519023', '514011', '533099', '499092', '519194', '359011',
#        '353011', '515111', '253999', '475013', '291128', '439799',
#        '475011', '299012', '472121', '339032', '519032', '439111',
#        '319093', '516091', '493051', '292056', '434199', '273099',
#        '532011', '131074', '202111', '194111', '201111', '193111',
#        '195111', '202211', '196111', '197111', '132082', '199911',
#        '192011', '201311', '193311', '198111', '519031', '191032',
#        '254031', '254013', '193211', '193911', '492021', '172052',
#        '419011', '292091', '419799', '194051', '519191', '299799',
#        '452011', '475071', '394831', '397011', '434041', '514061',
#        '536099', '474011', '252023', '231021', '434011', '291126',
#        '292031', '439199', '514032', '472131', '311014', '492091',
#        '272099', '519141', '292037', '419012', '475051', '516099',
#        '514199', '435032', '435051', '211798', '516041', '191031',
#        '312011', '517031', '393092', '537081', '472053', '472142',
#        '515112', '151143', '472132', '516064', '395011', '517041',
#        '512021', '151134', '151122', '472043', '151199', '499099',
#        '499799', '516063', '493052', '252052', '252059', '291141',
#        '434121', '151151', '492097', '291171', '271012', '434021',
#        '191099', '537073', '518031', '292099', '512022', '151152',
#        '434111', '119061', '272031', '396012', '319099', '512091',
#        '453011', '193093', '311013', '292053', '537063', '519197',
#        '513099', '537021', '292035', '395093', '499094', '359099',
#        '252051', '299092', '312012', '474021', '394031', '131131',
#        '493022', '211094', '537121', '151054', '151055', '452041',
#        '472082', '433099', '292041', '393091', '274013', '535031',
#        '532031', '433071', '519021', '272011', '512092', '532022',
#        '474051', '519012', '272023', '291129', '472171', '439021',
#        '516061', '516062', '132081', '533021', '454023', '513091',
#        '493091', '292057', '412022', '439041', '319094', '319095',
#        '339099', '319097', '299099', '472231', '537071', '515022'],
#       dtype=object)

# %%
#Finding "nan" values in "pw_soc_code" column and filling them with mode
df.loc[df['pw_soc_code'] == "nan",'pw_soc_code'] = df['pw_soc_code'].mode()[0]

#Finding "None" values in "pw_soc_code" column and filling them with mode
df.loc[df['pw_soc_code'] == "None",'pw_soc_code'] = df['pw_soc_code'].mode()[0]

# %%
df["pw_soc_code"] = df["pw_soc_code"].astype(int)
df["case_status"] = df["case_status"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 347157 entries, 0 to 365046
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   case_status           347157 non-null  int64
#  1   decision_date         347157 non-null  datetime64[ns]
#  2   employer_address_1    347120 non-null  object
#  3   employer_city         347147 non-null  object
#  4   employer_name         347149 non-null  object
#  5   employer_postal_code  347124 non-null  object
#  6   employer_state        347157 non-null  object
#  7   job_info_work_city    347064 non-null  object
#  8   job_info_work_state   347063 non-null  object
#  9   pw_amount_9089        344958 non-null  object
#  10  pw_soc_code           347157 non-null  int64
#  11  pw_soc_title          344842 non-null  object
#  12  pw_source_name_9089   345075 non-null  object
#  13  pw_unit_of_pay_9089   345678 non-null  object
#  14  case_numbers          347157 non-null  object
#  15  year                  347157 non-null  int32
#  16  month                 347157 non-null  int32
#  17  day                   347157 non-null  int32
# dtypes: datetime64[ns](1), int32(3), int64(2), object(12)
# memory usage: 46.4+ MB

# %%
# Replacing missing values with mode
#df['class_of_admission'] = df['class_of_admission'].fillna((df['class_of_admission'].mode()[0]))
#df['country_of_citizenship'] = df['country_of_citizenship'].fillna((df['country_of_citizenship'].mode()[0]))
df['employer_city'] = df['employer_city'].fillna((df['employer_city'].mode()[0]))
df['employer_name'] = df['employer_name'].fillna((df['employer_name'].mode()[0]))
df['employer_name'] = df['employer_name'].astype(str).str.upper()
df['pw_source_name_9089'] = df['pw_source_name_9089'].fillna((df['pw_source_name_9089'].mode()[0]))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 347157 entries, 0 to 365046
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   case_status           347157 non-null  int64
#  1   decision_date         347157 non-null  datetime64[ns]
#  2   employer_address_1    347120 non-null  object
#  3   employer_city         347157 non-null  object
#  4   employer_name         347157 non-null  object
#  5   employer_postal_code  347124 non-null  object
#  6   employer_state        347157 non-null  object
#  7   job_info_work_city    347064 non-null  object
#  8   job_info_work_state   347063 non-null  object
#  9   pw_amount_9089        344958 non-null  object
#  10  pw_soc_code           347157 non-null  int64
#  11  pw_soc_title          344842 non-null  object
#  12  pw_source_name_9089   347157 non-null  object
#  13  pw_unit_of_pay_9089   345678 non-null  object
#  14  case_numbers          347157 non-null  object
#  15  year                  347157 non-null  int32
#  16  month                 347157 non-null  int32
#  17  day                   347157 non-null  int32
# dtypes: datetime64[ns](1), int32(3), int64(2), object(12)
# memory usage: 46.4+ MB

# %%
df["pw_amount_9089"]
# Out:
# 0            75629.0
# 1            37024.0
# 2            47923.0
# 3              10.97
# 4            94890.0
#              ...
# 365042     98,426.00
# 365043     75,338.00
# 365044    116,355.00
# 365045     79,102.00
# 365046           NaN
# Name: pw_amount_9089, Length: 347157, dtype: object

# %%
# Convert the column containing numerical values with commas to numeric format
df['pw_amount_9089'] = df['pw_amount_9089'].str.replace(',', '').astype(float)

# Now, you can replace null values in the numerical column with the median
median_pw_amount = df['pw_amount_9089'].median()
df['pw_amount_9089'].fillna(median_pw_amount, inplace=True)

# Verify that there are no more null values
print(df.isnull().sum())
# Out:
# case_status                0
# decision_date              0
# employer_address_1        37
# employer_city              0
# employer_name              0
# employer_postal_code      33
# employer_state             0
# job_info_work_city        93
# job_info_work_state       94
# pw_amount_9089             0
# pw_soc_code                0
# pw_soc_title            2315
# pw_source_name_9089        0
# pw_unit_of_pay_9089     1479
# case_numbers               0
# year                       0
# month                      0
# day                        0
# dtype: int64
